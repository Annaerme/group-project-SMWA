# %% [markdown]
# # Project Overview
#
# ## Data
#
# ### Financials
#
# - **[Scraping Financials](Data/1_Bronze/Financials/Scraping_financials.ipynb)**
#   - [Scraping Financial Data](Data/1_Bronze/Financials/Scraping_financials.ipynb#scraping-financial-data)
#     - [Summary](Data/1_Bronze/Financials/Scraping_financials.ipynb#summary)
#
# ## Descriptive
#
# ### Bluesky
#
# - [1 Data Collection](Descriptive/Bluesky/1_Data_collection.ipynb)
# - **[2 Network Analysis](Descriptive/Bluesky/2_Network_analysis.ipynb)**
#   - [Bluesky US Election 2024 — Mention Network Analysis](Descriptive/Bluesky/2_Network_analysis.ipynb#bluesky-us-election-2024-mention-network-analysis)
#       - [Framing: buzz clusters, not supporter groups](Descriptive/Bluesky/2_Network_analysis.ipynb#framing-buzz-clusters-not-supporter-groups)
#     - [1 · Setup](Descriptive/Bluesky/2_Network_analysis.ipynb#1-setup)
#     - [2 · Data](Descriptive/Bluesky/2_Network_analysis.ipynb#2-data)
#     - [3 · Network Construction](Descriptive/Bluesky/2_Network_analysis.ipynb#3-network-construction)
#     - [4 · Network Structure & Statistics](Descriptive/Bluesky/2_Network_analysis.ipynb#4-network-structure-statistics)
#     - [5 · Degree Distribution](Descriptive/Bluesky/2_Network_analysis.ipynb#5-degree-distribution)
#       - [Insight — Power-law degree distribution](Descriptive/Bluesky/2_Network_analysis.ipynb#insight-power-law-degree-distribution)
#     - [6 · Centrality Analysis](Descriptive/Bluesky/2_Network_analysis.ipynb#6-centrality-analysis)
#       - [Insight — Who dominates the conversation?](Descriptive/Bluesky/2_Network_analysis.ipynb#insight-who-dominates-the-conversation)
#       - [Insight — Four types of accounts in the mention landscape](Descriptive/Bluesky/2_Network_analysis.ipynb#insight-four-types-of-accounts-in-the-mention-landscape)
#     - [7 · Echo Chamber Analysis](Descriptive/Bluesky/2_Network_analysis.ipynb#7-echo-chamber-analysis)
#       - [Insight — Hashtag spaces stay separate: a cluster bubble effect](Descriptive/Bluesky/2_Network_analysis.ipynb#insight-hashtag-spaces-stay-separate-a-cluster-bubble-effect)
#     - [8 · Network Visualisation](Descriptive/Bluesky/2_Network_analysis.ipynb#8-network-visualisation)
#       - [Insight — The topology of political conversation](Descriptive/Bluesky/2_Network_analysis.ipynb#insight-the-topology-of-political-conversation)
#     - [9 · Bridge Node Analysis](Descriptive/Bluesky/2_Network_analysis.ipynb#9-bridge-node-analysis)
#       - [Insight — Bridges vs cluster hubs: two very different types of accounts](Descriptive/Bluesky/2_Network_analysis.ipynb#insight-bridges-vs-cluster-hubs-two-very-different-types-of-accounts)
#     - [10 · Temporal Polarisation](Descriptive/Bluesky/2_Network_analysis.ipynb#10-temporal-polarisation)
#       - [Insight — Do hashtag spaces become more insular over time?](Descriptive/Bluesky/2_Network_analysis.ipynb#insight-do-hashtag-spaces-become-more-insular-over-time)
#     - [11 · Summary Dashboard](Descriptive/Bluesky/2_Network_analysis.ipynb#11-summary-dashboard)
#     - [Overall conclusions](Descriptive/Bluesky/2_Network_analysis.ipynb#overall-conclusions)
# - **[4 Textual Analysis](Descriptive/Bluesky/4_Textual_analysis.ipynb)**
#   - [Descriptive setup (no train test split)](Descriptive/Bluesky/4_Textual_analysis.ipynb#descriptive-setup-no-train-test-split)
#         - [Analyzing Review Length Distribution](Descriptive/Bluesky/4_Textual_analysis.ipynb#analyzing-review-length-distribution)
#         - [Word Count Distribution](Descriptive/Bluesky/4_Textual_analysis.ipynb#word-count-distribution)
#       - [Basic Preprocessing steps](Descriptive/Bluesky/4_Textual_analysis.ipynb#basic-preprocessing-steps)
#         - [Before vs. After Comparison](Descriptive/Bluesky/4_Textual_analysis.ipynb#before-vs-after-comparison)
#         - [Creating the Document-Term Matrix with TF-IDF](Descriptive/Bluesky/4_Textual_analysis.ipynb#creating-the-document-term-matrix-with-tf-idf)
#       - [SVD](Descriptive/Bluesky/4_Textual_analysis.ipynb#svd)
#         - [Interpreting Latent Concepts](Descriptive/Bluesky/4_Textual_analysis.ipynb#interpreting-latent-concepts)
#         - [Explained Variance](Descriptive/Bluesky/4_Textual_analysis.ipynb#explained-variance)
#   - [predictive setup --> create basetable for concatenation and feature engineering (train test split)](Descriptive/Bluesky/4_Textual_analysis.ipynb#predictive-setup----create-basetable-for-concatenation-and-feature-engineering-train-test-split)
# - **[5 Nlp](Descriptive/Bluesky/5_NLP.ipynb)**
#   - [Topic modeling](Descriptive/Bluesky/5_NLP.ipynb#topic-modeling)
#
# ### Financials
#
# - **[1 Descriptive](Descriptive/Financials/1_Descriptive.ipynb)**
#   - [Financial Markets — Descriptive Analysis](Descriptive/Financials/1_Descriptive.ipynb#financial-markets-descriptive-analysis)
#     - [1 — General](Descriptive/Financials/1_Descriptive.ipynb#1-general)
#       - [1.1 — Data Overview](Descriptive/Financials/1_Descriptive.ipynb#11-data-overview)
#       - [1.2 — Market Indicators Over Time](Descriptive/Financials/1_Descriptive.ipynb#12-market-indicators-over-time)
#       - [1.3 — Correlation Between Market Indicators](Descriptive/Financials/1_Descriptive.ipynb#13-correlation-between-market-indicators)
#       - [1.4 — S&P 500 vs. Market Volatility (VIX)](Descriptive/Financials/1_Descriptive.ipynb#14-sp-500-vs-market-volatility-vix)
#       - [1.5 — Macroeconomic Indicators](Descriptive/Financials/1_Descriptive.ipynb#15-macroeconomic-indicators)
#     - [2 — Events](Descriptive/Financials/1_Descriptive.ipynb#2-events)
#       - [2.1 — Market Reaction Around Each Event](Descriptive/Financials/1_Descriptive.ipynb#21-market-reaction-around-each-event)
#       - [2.2 — Indexed Performance Around Events](Descriptive/Financials/1_Descriptive.ipynb#22-indexed-performance-around-events)
#       - [2.3 — Market Impact Summary](Descriptive/Financials/1_Descriptive.ipynb#23-market-impact-summary)
#
# ### Google Trends
#
# - **[1 Data Collection](Descriptive/Google%20Trends/1_Data_collection.ipynb)**
#   - [Google Trends — Data Collection](Descriptive/Google%20Trends/1_Data_collection.ipynb#google-trends-data-collection)
#       - [Why US-only?](Descriptive/Google%20Trends/1_Data_collection.ipynb#why-us-only)
#       - [What is extracted?](Descriptive/Google%20Trends/1_Data_collection.ipynb#what-is-extracted)
#       - [Technical note — stitching windows](Descriptive/Google%20Trends/1_Data_collection.ipynb#technical-note-stitching-windows)
#     - [1. Fetch `interest_over_time` — all keywords](Descriptive/Google%20Trends/1_Data_collection.ipynb#1-fetch-interest_over_time-all-keywords)
#     - [2. Fetch `interest_by_region` (US states)](Descriptive/Google%20Trends/1_Data_collection.ipynb#2-fetch-interest_by_region-us-states)
#     - [4. Fetch daily `trump` time series per state](Descriptive/Google%20Trends/1_Data_collection.ipynb#4-fetch-daily-trump-time-series-per-state)
#     - [6. Fetch `related_queries`](Descriptive/Google%20Trends/1_Data_collection.ipynb#6-fetch-related_queries)
#     - [Summary](Descriptive/Google%20Trends/1_Data_collection.ipynb#summary)
# - **[2 Descriptive Analysis](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb)**
#   - [Google Trends — Descriptive Analysis](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#google-trends-descriptive-analysis)
#     - [1. Load & inspect](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#1-load-inspect)
#     - [2. All keywords over time](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#2-all-keywords-over-time)
#     - [3. Candidate comparison with key event annotations](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#3-candidate-comparison-with-key-event-annotations)
#     - [4. Trump–Harris search gap (daily difference)](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#4-trumpharris-search-gap-daily-difference)
#     - [5. Smoothed trends — 7-day rolling average](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#5-smoothed-trends-7-day-rolling-average)
#     - [6. Interest by US state — top states per candidate](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#6-interest-by-us-state-top-states-per-candidate)
#     - [7. Rising related queries — Trump vs Harris](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#7-rising-related-queries-trump-vs-harris)
#     - [8. Correlation with Polymarket odds](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#8-correlation-with-polymarket-odds)
#     - [Summary](Descriptive/Google%20Trends/2_Descriptive_analysis.ipynb#summary)
# - **[3 State Analysis](Descriptive/Google%20Trends/3_State_analysis.ipynb)**
#   - [Google Trends — State-Level Analysis](Descriptive/Google%20Trends/3_State_analysis.ipynb#google-trends-state-level-analysis)
#     - [1. Load & overview](Descriptive/Google%20Trends/3_State_analysis.ipynb#1-load-overview)
#     - [3. Search gap ranking — Trump minus Kamala](Descriptive/Google%20Trends/3_State_analysis.ipynb#3-search-gap-ranking-trump-minus-kamala)
#     - [4. Swing state focus](Descriptive/Google%20Trends/3_State_analysis.ipynb#4-swing-state-focus)
#     - [5. Home state effects — Walz & Vance](Descriptive/Google%20Trends/3_State_analysis.ipynb#5-home-state-effects-walz-vance)
#     - [6. `vote` search interest by state](Descriptive/Google%20Trends/3_State_analysis.ipynb#6-vote-search-interest-by-state)
#     - [8. Correlation heatmap across all keywords](Descriptive/Google%20Trends/3_State_analysis.ipynb#8-correlation-heatmap-across-all-keywords)
#     - [Summary](Descriptive/Google%20Trends/3_State_analysis.ipynb#summary)
#     - [7. `trump` search interest over time — all states (heatmap)](Descriptive/Google%20Trends/3_State_analysis.ipynb#7-trump-search-interest-over-time-all-states-heatmap)
#
# ### Newspapers
#
# - **[1 Retrieval Newspapers](Descriptive/Newspapers/1_retrieval_newspapers.ipynb)**
#   - [Newspaper Article Retrieval — 2024 US Presidential Election](Descriptive/Newspapers/1_retrieval_newspapers.ipynb#newspaper-article-retrieval-2024-us-presidential-election)
#     - [1. The Guardian API (Democratic-leaning)](Descriptive/Newspapers/1_retrieval_newspapers.ipynb#1-the-guardian-api-democratic-leaning)
#     - [2. New York Times Article Search API (Democratic-leaning)](Descriptive/Newspapers/1_retrieval_newspapers.ipynb#2-new-york-times-article-search-api-democratic-leaning)
#     - [3. GDELT DOC 2.0 — Fox News, Breitbart, NY Post (Republican) + NBC News (Democratic)](Descriptive/Newspapers/1_retrieval_newspapers.ipynb#3-gdelt-doc-20-fox-news-breitbart-ny-post-republican-nbc-news-democratic)
#     - [4. Combine All Sources & Save](Descriptive/Newspapers/1_retrieval_newspapers.ipynb#4-combine-all-sources-save)
# - **[2 Media Cloud](Descriptive/Newspapers/2_media_cloud.ipynb)**
#   - [Media Cloud — 2024 US Presidential Election Coverage](Descriptive/Newspapers/2_media_cloud.ipynb#media-cloud-2024-us-presidential-election-coverage)
#     - [Wat wordt verzameld](Descriptive/Newspapers/2_media_cloud.ipynb#wat-wordt-verzameld)
#     - [API key](Descriptive/Newspapers/2_media_cloud.ipynb#api-key)
#     - [1. Dagelijkse tellingen ophalen](Descriptive/Newspapers/2_media_cloud.ipynb#1-dagelijkse-tellingen-ophalen)
#     - [2. Feature engineering](Descriptive/Newspapers/2_media_cloud.ipynb#2-feature-engineering)
#     - [3. Visualisatie](Descriptive/Newspapers/2_media_cloud.ipynb#3-visualisatie)
#     - [4. Opslaan naar CSV](Descriptive/Newspapers/2_media_cloud.ipynb#4-opslaan-naar-csv)
#     - [5. (Optioneel) Individuele artikelen ophalen voor sentimentanalyse](Descriptive/Newspapers/2_media_cloud.ipynb#5-optioneel-individuele-artikelen-ophalen-voor-sentimentanalyse)
#     - [6. Fix: ontbrekende dagen 14–18 oktober opnieuw ophalen](Descriptive/Newspapers/2_media_cloud.ipynb#6-fix-ontbrekende-dagen-1418-oktober-opnieuw-ophalen)
# - **[3 Combining Newspapers Mediacloud](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb)**
#   - [Combining Newspapers + MediaCloud](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb#combining-newspapers-mediacloud)
#     - [1. Load Both Datasets](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb#1-load-both-datasets)
#     - [2. Assign Political Leaning to MediaCloud Sources](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb#2-assign-political-leaning-to-mediacloud-sources)
#     - [3. Standardise MediaCloud to Match Scraped Columns](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb#3-standardise-mediacloud-to-match-scraped-columns)
#     - [4. Combine & Deduplicate](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb#4-combine-deduplicate)
#     - [4b. Clean Source Names](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb#4b-clean-source-names)
#     - [5. Save to Silver Layer](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb#5-save-to-silver-layer)
#     - [6. Quick Overview](Descriptive/Newspapers/3_combining_newspapers_mediacloud.ipynb#6-quick-overview)
# - **[4 Textual Analysis](Descriptive/Newspapers/4_Textual_analysis.ipynb)**
#   - [Textual Analysis — Newspaper Headlines (2024 US Presidential Election)](Descriptive/Newspapers/4_Textual_analysis.ipynb#textual-analysis-newspaper-headlines-2024-us-presidential-election)
#     - [1. Text Preprocessing](Descriptive/Newspapers/4_Textual_analysis.ipynb#1-text-preprocessing)
#     - [2. Word Clouds](Descriptive/Newspapers/4_Textual_analysis.ipynb#2-word-clouds)
#     - [3. TF-IDF Analysis — Most Distinctive Words per Leaning](Descriptive/Newspapers/4_Textual_analysis.ipynb#3-tf-idf-analysis-most-distinctive-words-per-leaning)
#     - [4. SVD / Latent Semantic Analysis (LSA)](Descriptive/Newspapers/4_Textual_analysis.ipynb#4-svd-latent-semantic-analysis-lsa)
#     - [5. Word Co-occurrence Networks](Descriptive/Newspapers/4_Textual_analysis.ipynb#5-word-co-occurrence-networks)
#     - [6. Key Term Frequency Over Time](Descriptive/Newspapers/4_Textual_analysis.ipynb#6-key-term-frequency-over-time)
#     - [7. Basetable Features — Textual Analysis](Descriptive/Newspapers/4_Textual_analysis.ipynb#7-basetable-features-textual-analysis)
# - **[5 Nlp](Descriptive/Newspapers/5_NLP.ipynb)**
#   - [NLP Analysis — Newspaper Headlines (2024 US Presidential Election)](Descriptive/Newspapers/5_NLP.ipynb#nlp-analysis-newspaper-headlines-2024-us-presidential-election)
#     - [1. POS Tagging](Descriptive/Newspapers/5_NLP.ipynb#1-pos-tagging)
#     - [2. Named Entity Recognition (NER)](Descriptive/Newspapers/5_NLP.ipynb#2-named-entity-recognition-ner)
#     - [3. Word Embeddings — Word2Vec (Trump-focused)](Descriptive/Newspapers/5_NLP.ipynb#3-word-embeddings-word2vec-trump-focused)
#       - [3b. Trump Sentiment Score via Embedding Projection](Descriptive/Newspapers/5_NLP.ipynb#3b-trump-sentiment-score-via-embedding-projection)
#     - [4. Word Embeddings — GloVe (pre-trained)](Descriptive/Newspapers/5_NLP.ipynb#4-word-embeddings-glove-pre-trained)
#     - [5. Dimensionality Reduction — t-SNE & UMAP](Descriptive/Newspapers/5_NLP.ipynb#5-dimensionality-reduction-t-sne-umap)
#     - [6. Topic Modelling — LDA](Descriptive/Newspapers/5_NLP.ipynb#6-topic-modelling-lda)
#     - [7. Basetable Features](Descriptive/Newspapers/5_NLP.ipynb#7-basetable-features)
# - **[6 Analysis](Descriptive/Newspapers/6_analysis.ipynb)**
#   - [Sentiment Analysis — Newspaper Headlines (2024 US Presidential Election)](Descriptive/Newspapers/6_analysis.ipynb#sentiment-analysis-newspaper-headlines-2024-us-presidential-election)
#   - [── 1. Load & inspect ─────────────────────────────────────────────────────────────────](Descriptive/Newspapers/6_analysis.ipynb#1-load-inspect)
#   - [── 2. VADER Sentiment Analysis ────────────────────────────────────────────────────](Descriptive/Newspapers/6_analysis.ipynb#2-vader-sentiment-analysis)
#   - [── 3. NRCLex Emotion Analysis ──────────────────────────────────────────────────](Descriptive/Newspapers/6_analysis.ipynb#3-nrclex-emotion-analysis)
#   - [── 5. Feature Engineering & Export ────────────────────────────────────────────](Descriptive/Newspapers/6_analysis.ipynb#5-feature-engineering-export)
# - **[7 Cross Source Analysis](Descriptive/Newspapers/7_cross_source_analysis.ipynb)**
#   - [Cross-Source Analysis — Newspapers × Polymarket × Polls × Markets](Descriptive/Newspapers/7_cross_source_analysis.ipynb#cross-source-analysis-newspapers-polymarket-polls-markets)
#   - [── 1. Load & merge all data sources ───────────────────────────────────────────](Descriptive/Newspapers/7_cross_source_analysis.ipynb#1-load-merge-all-data-sources)
#   - [── 2. Media Attention × Polymarket Odds ───────────────────────────────────────](Descriptive/Newspapers/7_cross_source_analysis.ipynb#2-media-attention-polymarket-odds)
#       - [Key Takeaways — Media Attention × Polymarket Odds](Descriptive/Newspapers/7_cross_source_analysis.ipynb#key-takeaways-media-attention-polymarket-odds)
#   - [── 3. Newspaper Sentiment × Polymarket Odds ─────────────────────────────────](Descriptive/Newspapers/7_cross_source_analysis.ipynb#3-newspaper-sentiment-polymarket-odds)
#       - [Key Takeaways — Newspaper Sentiment × Polymarket Odds](Descriptive/Newspapers/7_cross_source_analysis.ipynb#key-takeaways-newspaper-sentiment-polymarket-odds)
#   - [── 4. Newspaper Emotions × Financial Markets ────────────────────────────────](Descriptive/Newspapers/7_cross_source_analysis.ipynb#4-newspaper-emotions-financial-markets)
#       - [Key Takeaways — Newspaper Emotions × Financial Markets](Descriptive/Newspapers/7_cross_source_analysis.ipynb#key-takeaways-newspaper-emotions-financial-markets)
#   - [── 5. Polls × Newspaper Coverage & Sentiment ────────────────────────────────](Descriptive/Newspapers/7_cross_source_analysis.ipynb#5-polls-newspaper-coverage-sentiment)
#       - [Key Takeaways — Polls × Newspaper Coverage & Sentiment](Descriptive/Newspapers/7_cross_source_analysis.ipynb#key-takeaways-polls-newspaper-coverage-sentiment)
#   - [── 6. Correlation Overview ────────────────────────────────────────────────────](Descriptive/Newspapers/7_cross_source_analysis.ipynb#6-correlation-overview)
#       - [Key Takeaways — Correlation Overview](Descriptive/Newspapers/7_cross_source_analysis.ipynb#key-takeaways-correlation-overview)
#   - [── 7. Key-Events Timeline — All Signals at a Glance ─────────────────────────](Descriptive/Newspapers/7_cross_source_analysis.ipynb#7-key-events-timeline-all-signals-at-a-glance)
#       - [Key Takeaways — Key-Events Timeline](Descriptive/Newspapers/7_cross_source_analysis.ipynb#key-takeaways-key-events-timeline)
#
# ### Polls
#
# - **[1 Data Collection](Descriptive/Polls/1_Data_collection.ipynb)**
#   - [Wikipedia Polls — Data Collection](Descriptive/Polls/1_Data_collection.ipynb#wikipedia-polls-data-collection)
#     - [Why Wikipedia?](Descriptive/Polls/1_Data_collection.ipynb#why-wikipedia)
#     - [What we collect](Descriptive/Polls/1_Data_collection.ipynb#what-we-collect)
#     - [0. Setup](Descriptive/Polls/1_Data_collection.ipynb#0-setup)
#     - [1. Scraping with BeautifulSoup](Descriptive/Polls/1_Data_collection.ipynb#1-scraping-with-beautifulsoup)
#       - [1.1 Fetch the page](Descriptive/Polls/1_Data_collection.ipynb#11-fetch-the-page)
#       - [1.2 Parse HTML structure with BeautifulSoup](Descriptive/Polls/1_Data_collection.ipynb#12-parse-html-structure-with-beautifulsoup)
#       - [1.3 Select relevant tables and convert to DataFrames](Descriptive/Polls/1_Data_collection.ipynb#13-select-relevant-tables-and-convert-to-dataframes)
#     - [2. Data Cleaning](Descriptive/Polls/1_Data_collection.ipynb#2-data-cleaning)
#     - [3. Save to Bronze](Descriptive/Polls/1_Data_collection.ipynb#3-save-to-bronze)
# - **[2 Descriptive Analysis](Descriptive/Polls/2_Descriptive_analysis.ipynb)**
#   - [Wikipedia Polls — Descriptive Analysis](Descriptive/Polls/2_Descriptive_analysis.ipynb#wikipedia-polls-descriptive-analysis)
#     - [What are polls and why do we use them?](Descriptive/Polls/2_Descriptive_analysis.ipynb#what-are-polls-and-why-do-we-use-them)
#     - [What this notebook does](Descriptive/Polls/2_Descriptive_analysis.ipynb#what-this-notebook-does)
#     - [0. Setup](Descriptive/Polls/2_Descriptive_analysis.ipynb#0-setup)
#     - [1. Load data](Descriptive/Polls/2_Descriptive_analysis.ipynb#1-load-data)
#     - [2. Overview](Descriptive/Polls/2_Descriptive_analysis.ipynb#2-overview)
#     - [3. Polling averages over time](Descriptive/Polls/2_Descriptive_analysis.ipynb#3-polling-averages-over-time)
#       - [3.1 7-day rolling average with event annotations](Descriptive/Polls/2_Descriptive_analysis.ipynb#31-7-day-rolling-average-with-event-annotations)
#       - [3.2 Trump–Harris margin over time](Descriptive/Polls/2_Descriptive_analysis.ipynb#32-trumpharris-margin-over-time)
#       - [3.3 Distribution of poll support](Descriptive/Polls/2_Descriptive_analysis.ipynb#33-distribution-of-poll-support)
#       - [3.4 Monthly averages](Descriptive/Polls/2_Descriptive_analysis.ipynb#34-monthly-averages)
#       - [3.5 Average margin per pollster](Descriptive/Polls/2_Descriptive_analysis.ipynb#35-average-margin-per-pollster)
#     - [4. Summary](Descriptive/Polls/2_Descriptive_analysis.ipynb#4-summary)
#       - [Key findings](Descriptive/Polls/2_Descriptive_analysis.ipynb#key-findings)
#       - [Features for the basetable](Descriptive/Polls/2_Descriptive_analysis.ipynb#features-for-the-basetable)
#
# ### Polymarket
#
# - [Polymarket](Descriptive/Polymarket/polymarket.ipynb)
#
# ### Reddit
#
# - **[1 Data Collection](Descriptive/Reddit/1_Data_collection.ipynb)**
#   - [1. Setup](Descriptive/Reddit/1_Data_collection.ipynb#1-setup)
#   - [2. Remove duplicates & missing values](Descriptive/Reddit/1_Data_collection.ipynb#2-remove-duplicates-missing-values)
#   - [3. Remove deleted/removed comments](Descriptive/Reddit/1_Data_collection.ipynb#3-remove-deletedremoved-comments)
#   - [4. Text cleaning function](Descriptive/Reddit/1_Data_collection.ipynb#4-text-cleaning-function)
#   - [5. Apply cleaning](Descriptive/Reddit/1_Data_collection.ipynb#5-apply-cleaning)
#   - [6. Remove empty / low-quality comments](Descriptive/Reddit/1_Data_collection.ipynb#6-remove-empty-low-quality-comments)
#   - [7. Final clean check](Descriptive/Reddit/1_Data_collection.ipynb#7-final-clean-check)
#   - [8. Save cleaned data](Descriptive/Reddit/1_Data_collection.ipynb#8-save-cleaned-data)
# - **[1 Preprocessing](Descriptive/Reddit/1_Preprocessing.ipynb)**
#   - [Reddit — Preprocessing](Descriptive/Reddit/1_Preprocessing.ipynb#reddit-preprocessing)
#     - [1. Helper functions](Descriptive/Reddit/1_Preprocessing.ipynb#1-helper-functions)
#     - [2. Load & combine all comments](Descriptive/Reddit/1_Preprocessing.ipynb#2-load-combine-all-comments)
#     - [3. Load posts](Descriptive/Reddit/1_Preprocessing.ipynb#3-load-posts)
#     - [4. Quick check](Descriptive/Reddit/1_Preprocessing.ipynb#4-quick-check)
# - **[2 Network Analysis](Descriptive/Reddit/2_Network_analysis.ipynb)**
#   - [Reddit — Network Analysis](Descriptive/Reddit/2_Network_analysis.ipynb#reddit-network-analysis)
#     - [1. User-user Reply Network](Descriptive/Reddit/2_Network_analysis.ipynb#1-user-user-reply-network)
#     - [2. Author Activity — Cross-subreddit Overlap](Descriptive/Reddit/2_Network_analysis.ipynb#2-author-activity-cross-subreddit-overlap)
#     - [3. Post-Comment Bipartite Network — Engagement](Descriptive/Reddit/2_Network_analysis.ipynb#3-post-comment-bipartite-network-engagement)
# - **[3 Textual Analysis](Descriptive/Reddit/3_Textual_analysis.ipynb)**
#       - [Politics posts](Descriptive/Reddit/3_Textual_analysis.ipynb#politics-posts)
#       - [Worldnews posts](Descriptive/Reddit/3_Textual_analysis.ipynb#worldnews-posts)
#       - [Conservative posts](Descriptive/Reddit/3_Textual_analysis.ipynb#conservative-posts)
#       - [Conservative comments](Descriptive/Reddit/3_Textual_analysis.ipynb#conservative-comments)
#     - [Concatenate all posts](Descriptive/Reddit/3_Textual_analysis.ipynb#concatenate-all-posts)
#   - [Descriptive setup (no train test split)](Descriptive/Reddit/3_Textual_analysis.ipynb#descriptive-setup-no-train-test-split)
#         - [Analyzing Review Length Distribution](Descriptive/Reddit/3_Textual_analysis.ipynb#analyzing-review-length-distribution)
#         - [Word Count Distribution](Descriptive/Reddit/3_Textual_analysis.ipynb#word-count-distribution)
#       - [Basic Preprocessing steps](Descriptive/Reddit/3_Textual_analysis.ipynb#basic-preprocessing-steps)
#         - [Before vs. After Comparison](Descriptive/Reddit/3_Textual_analysis.ipynb#before-vs-after-comparison)
#         - [Creating the Document-Term Matrix with TF-IDF](Descriptive/Reddit/3_Textual_analysis.ipynb#creating-the-document-term-matrix-with-tf-idf)
#       - [SVD](Descriptive/Reddit/3_Textual_analysis.ipynb#svd)
#         - [Interpreting Latent Concepts](Descriptive/Reddit/3_Textual_analysis.ipynb#interpreting-latent-concepts)
#         - [Explained Variance](Descriptive/Reddit/3_Textual_analysis.ipynb#explained-variance)
#   - [predictive setup --> create basetable for concatenation and feature engineering (train test split)](Descriptive/Reddit/3_Textual_analysis.ipynb#predictive-setup----create-basetable-for-concatenation-and-feature-engineering-train-test-split)
# - **[3 Wordclouds](Descriptive/Reddit/3_Wordclouds.ipynb)**
#   - [Reddit — Wordclouds & Tekstuele Analyse](Descriptive/Reddit/3_Wordclouds.ipynb#reddit-wordclouds-tekstuele-analyse)
#     - [1. Wordclouds Comments — per Subreddit](Descriptive/Reddit/3_Wordclouds.ipynb#1-wordclouds-comments-per-subreddit)
#     - [2. Wordclouds Post-titels — per Subreddit](Descriptive/Reddit/3_Wordclouds.ipynb#2-wordclouds-post-titels-per-subreddit)
#     - [3. Per-Candidate Wordclouds](Descriptive/Reddit/3_Wordclouds.ipynb#3-per-candidate-wordclouds)
#     - [4. TF-IDF — Characteristic Words per Subreddit](Descriptive/Reddit/3_Wordclouds.ipynb#4-tf-idf-characteristic-words-per-subreddit)
# - **[4 Sentiment Analysis](Descriptive/Reddit/4_Sentiment_analysis.ipynb)**
#   - [Reddit — Sentiment Analysis](Descriptive/Reddit/4_Sentiment_analysis.ipynb#reddit-sentiment-analysis)
#     - [1. Sentiment Time Series per Subreddit](Descriptive/Reddit/4_Sentiment_analysis.ipynb#1-sentiment-time-series-per-subreddit)
#     - [2. Candidate Sentiment per Subreddit](Descriptive/Reddit/4_Sentiment_analysis.ipynb#2-candidate-sentiment-per-subreddit)
#     - [3. Polarisation Metrics](Descriptive/Reddit/4_Sentiment_analysis.ipynb#3-polarisation-metrics)
#
# ## Predictive
#
# - **[Basetable](Predictive/basetable.ipynb)**
#   - [Basetable — 2024 US Presidential Election](Predictive/basetable.ipynb#basetable-2024-us-presidential-election)
#     - [Variable Overview](Predictive/basetable.ipynb#variable-overview)
#   - [1. Time Dimension](Predictive/basetable.ipynb#1-time-dimension)
#   - [2. Bluesky](Predictive/basetable.ipynb#2-bluesky)
#     - [General](Predictive/basetable.ipynb#general)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#     - [Network](Predictive/basetable.ipynb#network)
#   - [3. Reddit](Predictive/basetable.ipynb#3-reddit)
#     - [General](Predictive/basetable.ipynb#general)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#   - [4. Newspapers](Predictive/basetable.ipynb#4-newspapers)
#     - [Volume & Attention](Predictive/basetable.ipynb#volume-attention)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#     - [Topics](Predictive/basetable.ipynb#topics)
#   - [5. Financials](Predictive/basetable.ipynb#5-financials)
#     - [Market data (daily)](Predictive/basetable.ipynb#market-data-daily)
#     - [Macro data (monthly)](Predictive/basetable.ipynb#macro-data-monthly)
#   - [6. Political Data](Predictive/basetable.ipynb#6-political-data)
#     - [Events](Predictive/basetable.ipynb#events)
#     - [Polls](Predictive/basetable.ipynb#polls)
#   - [7. Lag Features (t-1)](Predictive/basetable.ipynb#7-lag-features-t-1)
# - **[Modela](Predictive/modelA.ipynb)**
#   - [Notebook A — Predicting Polymarket Price Level](Predictive/modelA.ipynb#notebook-a-predicting-polymarket-price-level)
#     - [2024 US Presidential Election — Walk-Forward Machine Learning](Predictive/modelA.ipynb#2024-us-presidential-election-walk-forward-machine-learning)
#     - [1. Setup](Predictive/modelA.ipynb#1-setup)
#     - [2. Data Loading & Feature Groups](Predictive/modelA.ipynb#2-data-loading-feature-groups)
#     - [3. Walk-Forward CV Splits](Predictive/modelA.ipynb#3-walk-forward-cv-splits)
#       - [Why walk-forward (not k-fold)?](Predictive/modelA.ipynb#why-walk-forward-not-k-fold)
#       - [No fit-transform leakage](Predictive/modelA.ipynb#no-fit-transform-leakage)
#     - [4. Preprocessing Pipeline (No Leakage)](Predictive/modelA.ipynb#4-preprocessing-pipeline-no-leakage)
#     - [5. Hyperparameter Tuning](Predictive/modelA.ipynb#5-hyperparameter-tuning)
#     - [6. Tuning Results](Predictive/modelA.ipynb#6-tuning-results)
#     - [7. Walk-Forward CV Evaluation](Predictive/modelA.ipynb#7-walk-forward-cv-evaluation)
#     - [8. Results](Predictive/modelA.ipynb#8-results)
#     - [9. Predictions vs Actual — Best Model](Predictive/modelA.ipynb#9-predictions-vs-actual-best-model)
#     - [10. Feature Importance](Predictive/modelA.ipynb#10-feature-importance)
#     - [Feature Relevance — Model-free Correlation with Price Level](Predictive/modelA.ipynb#feature-relevance-model-free-correlation-with-price-level)
#     - [11. Final Test Set Evaluation](Predictive/modelA.ipynb#11-final-test-set-evaluation)
# - **[Modelb](Predictive/modelB.ipynb)**
#   - [Notebook B — Predicting Daily Price Changes (First Differences)](Predictive/modelB.ipynb#notebook-b-predicting-daily-price-changes-first-differences)
#     - [2024 US Presidential Election — Walk-Forward Machine Learning](Predictive/modelB.ipynb#2024-us-presidential-election-walk-forward-machine-learning)
#     - [1. Setup](Predictive/modelB.ipynb#1-setup)
#     - [2. Data Loading](Predictive/modelB.ipynb#2-data-loading)
#     - [3. Feature Engineering](Predictive/modelB.ipynb#3-feature-engineering)
#     - [4. Target: Daily Price Change](Predictive/modelB.ipynb#4-target-daily-price-change)
#     - [5. Feature Groups](Predictive/modelB.ipynb#5-feature-groups)
#     - [6. Walk-Forward CV Splits](Predictive/modelB.ipynb#6-walk-forward-cv-splits)
#     - [7. Preprocessing Pipeline](Predictive/modelB.ipynb#7-preprocessing-pipeline)
#     - [8. Hyperparameter Tuning](Predictive/modelB.ipynb#8-hyperparameter-tuning)
#     - [9. Cross-Validation Results](Predictive/modelB.ipynb#9-cross-validation-results)
#     - [Key Finding: Market Efficiency Evidence](Predictive/modelB.ipynb#key-finding-market-efficiency-evidence)
#     - [10. Results](Predictive/modelB.ipynb#10-results)
#     - [11. Predictions vs Actual](Predictive/modelB.ipynb#11-predictions-vs-actual)
#     - [12. Feature Importance](Predictive/modelB.ipynb#12-feature-importance)
#     - [Feature Relevance — Model-free Correlation with Target](Predictive/modelB.ipynb#feature-relevance-model-free-correlation-with-target)
#     - [13. Held-Out Test Set Evaluation](Predictive/modelB.ipynb#13-held-out-test-set-evaluation)
#     - [14. Summary & Market Efficiency](Predictive/modelB.ipynb#14-summary-market-efficiency)
# - **[Text Features](Predictive/text_features.ipynb)**
#   - [Text Features — Raw Daily Text Aggregation](Predictive/text_features.ipynb#text-features-raw-daily-text-aggregation)
#     - [Why save raw text instead of pre-computed TF-IDF?](Predictive/text_features.ipynb#why-save-raw-text-instead-of-pre-computed-tf-idf)
#     - [Setup](Predictive/text_features.ipynb#setup)
#     - [Load & align on basetable dates](Predictive/text_features.ipynb#load-align-on-basetable-dates)
#     - [Quick vocabulary check](Predictive/text_features.ipynb#quick-vocabulary-check)
#     - [Save](Predictive/text_features.ipynb#save)
