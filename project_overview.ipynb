# %% [markdown]
# # Project Overview
#
# ## Descriptive
#
# ### 0_polymarket
#
# - **[0.1 Eda](Descriptive/0_polymarket/0.1_eda.ipynb)**
#   - [Win Probabilities Over Time](Descriptive/0_polymarket/0.1_eda.ipynb#win-probabilities-over-time)
#   - [Trump – Harris Spread](Descriptive/0_polymarket/0.1_eda.ipynb#trump-harris-spread)
#   - [Probability Around Key Events  (indexed)](Descriptive/0_polymarket/0.1_eda.ipynb#probability-around-key-events-indexed)
#   - [Event Summary Table](Descriptive/0_polymarket/0.1_eda.ipynb#event-summary-table)
#
# ### 1_reddit
#
# - **[1.1 Eda](Descriptive/1_reddit/1.1_eda.ipynb)**
#   - [1. Bronze — raw data structure](Descriptive/1_reddit/1.1_eda.ipynb#1-bronze-raw-data-structure)
#   - [2. Text preprocessing → Buzz labels → Silver](Descriptive/1_reddit/1.1_eda.ipynb#2-text-preprocessing-buzz-labels-silver)
#   - [3. Exploratory Analysis](Descriptive/1_reddit/1.1_eda.ipynb#3-exploratory-analysis)
#     - [Key counts per candidate](Descriptive/1_reddit/1.1_eda.ipynb#key-counts-per-candidate)
#     - [Posts by subreddit](Descriptive/1_reddit/1.1_eda.ipynb#posts-by-subreddit)
#     - [Daily post volume](Descriptive/1_reddit/1.1_eda.ipynb#daily-post-volume)
#     - [Score distribution (log scale)](Descriptive/1_reddit/1.1_eda.ipynb#score-distribution-log-scale)
#     - [Word count distribution](Descriptive/1_reddit/1.1_eda.ipynb#word-count-distribution)
# - **[1.2 Network Analysis](Descriptive/1_reddit/1.2_network_analysis.ipynb)**
#   - [1. User-user Reply Network](Descriptive/1_reddit/1.2_network_analysis.ipynb#1-user-user-reply-network)
#   - [2. Author Activity Cross-subreddit Overlap](Descriptive/1_reddit/1.2_network_analysis.ipynb#2-author-activity-cross-subreddit-overlap)
#   - [3. Post-Comment Bipartite Network Engagement](Descriptive/1_reddit/1.2_network_analysis.ipynb#3-post-comment-bipartite-network-engagement)
# - **[1.3 Textual Analysis](Descriptive/1_reddit/1.3_textual_analysis.ipynb)**
#         - [Analyzing Review Length Distribution](Descriptive/1_reddit/1.3_textual_analysis.ipynb#analyzing-review-length-distribution)
#         - [Word Count Distribution](Descriptive/1_reddit/1.3_textual_analysis.ipynb#word-count-distribution)
#         - [Before vs. After Comparison](Descriptive/1_reddit/1.3_textual_analysis.ipynb#before-vs-after-comparison)
#         - [Creating the Document-Term Matrix with TF-IDF](Descriptive/1_reddit/1.3_textual_analysis.ipynb#creating-the-document-term-matrix-with-tf-idf)
#       - [SVD](Descriptive/1_reddit/1.3_textual_analysis.ipynb#svd)
#         - [Interpreting Latent Concepts](Descriptive/1_reddit/1.3_textual_analysis.ipynb#interpreting-latent-concepts)
#         - [Explained Variance](Descriptive/1_reddit/1.3_textual_analysis.ipynb#explained-variance)
#   - [predictive setup --> create basetable for concatenation and feature engineering (train test split)](Descriptive/1_reddit/1.3_textual_analysis.ipynb#predictive-setup----create-basetable-for-concatenation-and-feature-engineering-train-test-split)
# - **[1.4 Sentiment Analysis](Descriptive/1_reddit/1.4_Sentiment_analysis.ipynb)**
#   - [1. Sentiment Time Series per Subreddit](Descriptive/1_reddit/1.4_Sentiment_analysis.ipynb#1-sentiment-time-series-per-subreddit)
#   - [2. Candidate Sentiment per Subreddit](Descriptive/1_reddit/1.4_Sentiment_analysis.ipynb#2-candidate-sentiment-per-subreddit)
#   - [3. Polarisation Metrics](Descriptive/1_reddit/1.4_Sentiment_analysis.ipynb#3-polarisation-metrics)
# - **[1.4 Wordclouds](Descriptive/1_reddit/1.4_wordclouds.ipynb)**
#   - [1. Wordclouds Comments per Subreddit](Descriptive/1_reddit/1.4_wordclouds.ipynb#1-wordclouds-comments-per-subreddit)
#   - [2. Wordclouds Post-titels per Subreddit](Descriptive/1_reddit/1.4_wordclouds.ipynb#2-wordclouds-post-titels-per-subreddit)
#   - [3. Per-Candidate Wordclouds](Descriptive/1_reddit/1.4_wordclouds.ipynb#3-per-candidate-wordclouds)
#   - [4. TF-IDF Characteristic Words per Subreddit](Descriptive/1_reddit/1.4_wordclouds.ipynb#4-tf-idf-characteristic-words-per-subreddit)
#
# ### 2_bluesky
#
# - **[2.1 Eda](Descriptive/2_bluesky/2.1_eda.ipynb)**
#   - [1. Bronze — raw data structure](Descriptive/2_bluesky/2.1_eda.ipynb#1-bronze-raw-data-structure)
#   - [2. Text preprocessing → Buzz labels → Silver](Descriptive/2_bluesky/2.1_eda.ipynb#2-text-preprocessing-buzz-labels-silver)
#   - [3. Exploratory Analysis](Descriptive/2_bluesky/2.1_eda.ipynb#3-exploratory-analysis)
#     - [Key counts per candidate](Descriptive/2_bluesky/2.1_eda.ipynb#key-counts-per-candidate)
#     - [Daily post volume](Descriptive/2_bluesky/2.1_eda.ipynb#daily-post-volume)
#     - [Like distribution (log scale)](Descriptive/2_bluesky/2.1_eda.ipynb#like-distribution-log-scale)
# - **[2.2 Network Analysis](Descriptive/2_bluesky/2.2_network_analysis.ipynb)**
#     - [Framing: buzz clusters, not supporter groups](Descriptive/2_bluesky/2.2_network_analysis.ipynb#framing-buzz-clusters-not-supporter-groups)
#   - [1 · Setup](Descriptive/2_bluesky/2.2_network_analysis.ipynb#1-setup)
#   - [2 · Data](Descriptive/2_bluesky/2.2_network_analysis.ipynb#2-data)
#   - [3 · Network Construction](Descriptive/2_bluesky/2.2_network_analysis.ipynb#3-network-construction)
#   - [4 · Network Structure & Statistics](Descriptive/2_bluesky/2.2_network_analysis.ipynb#4-network-structure-statistics)
#   - [5 · Degree Distribution](Descriptive/2_bluesky/2.2_network_analysis.ipynb#5-degree-distribution)
#     - [Insight Power-law degree distribution](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-power-law-degree-distribution)
#   - [6 · Centrality Analysis](Descriptive/2_bluesky/2.2_network_analysis.ipynb#6-centrality-analysis)
#     - [Insight Who dominates the conversation?](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-who-dominates-the-conversation)
#     - [Insight Four types of accounts in the mention landscape](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-four-types-of-accounts-in-the-mention-landscape)
#   - [7 · Echo Chamber Analysis](Descriptive/2_bluesky/2.2_network_analysis.ipynb#7-echo-chamber-analysis)
#     - [Insight Hashtag spaces stay separate: a cluster bubble effect](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-hashtag-spaces-stay-separate-a-cluster-bubble-effect)
#   - [8 · Network Visualisation](Descriptive/2_bluesky/2.2_network_analysis.ipynb#8-network-visualisation)
#     - [Insight The topology of political conversation](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-the-topology-of-political-conversation)
#   - [9 · Bridge Node Analysis](Descriptive/2_bluesky/2.2_network_analysis.ipynb#9-bridge-node-analysis)
#     - [Insight Bridges vs cluster hubs: two very different types of accounts](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-bridges-vs-cluster-hubs-two-very-different-types-of-accounts)
#   - [10 · Temporal Polarisation](Descriptive/2_bluesky/2.2_network_analysis.ipynb#10-temporal-polarisation)
#     - [Insight Do hashtag spaces become more insular over time?](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-do-hashtag-spaces-become-more-insular-over-time)
#   - [11 · Summary Dashboard](Descriptive/2_bluesky/2.2_network_analysis.ipynb#11-summary-dashboard)
#   - [Overall conclusions](Descriptive/2_bluesky/2.2_network_analysis.ipynb#overall-conclusions)
# - **[2.3 Textual Analysis](Descriptive/2_bluesky/2.3_textual_analysis.ipynb)**
#   - [Content](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#content)
#     - [Analyzing review length distribution](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#analyzing-review-length-distribution)
#     - [Word count distribution](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#word-count-distribution)
#     - [Apply buzz column](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#apply-buzz-column)
#     - [Text preprocessing](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#text-preprocessing)
#       - [test preprocessing function first](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#test-preprocessing-function-first)
#       - [Preprocessing](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#preprocessing)
#     - [Before vs. after comparison](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#before-vs-after-comparison)
#     - [Creating the document-term matrix with tf-idf](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#creating-the-document-term-matrix-with-tf-idf)
#     - [SVD](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#svd)
#       - [Interpreting Latent Concepts](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#interpreting-latent-concepts)
#       - [Explained Variance](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#explained-variance)
#     - [Key term frequency over time](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#key-term-frequency-over-time)
#   - [Wordclouds](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#wordclouds)
# - **[2.4 Nlp](Descriptive/2_bluesky/2.4_nlp.ipynb)**
#     - [LDA topic modeling](Descriptive/2_bluesky/2.4_nlp.ipynb#lda-topic-modeling)
#     - [1 : Preprocessing](Descriptive/2_bluesky/2.4_nlp.ipynb#1-preprocessing)
#     - [2 : LDA — Build Dictionary & Corpus](Descriptive/2_bluesky/2.4_nlp.ipynb#2-lda-build-dictionary-corpus)
#     - [3 : LDA — Coherence Score and AIC: choosing optimal topic amount](Descriptive/2_bluesky/2.4_nlp.ipynb#3-lda-coherence-score-and-aic-choosing-optimal-topic-amount)
#     - [4 : LDA — Train Final Model](Descriptive/2_bluesky/2.4_nlp.ipynb#4-lda-train-final-model)
#   - [Topic per buzz group](Descriptive/2_bluesky/2.4_nlp.ipynb#topic-per-buzz-group)
# - **[2.5 Sentiment Analysis](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb)**
#   - [0. Setup](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#0-setup)
#   - [1. Load data](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#1-load-data)
#   - [2. VADER](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#2-vader)
#   - [3. Twitter-RoBERTa](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#3-twitter-roberta)
#   - [4. TextBlob](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#4-textblob)
#   - [5. NRCLex — Emotion Detection](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#5-nrclex-emotion-detection)
#   - [6. Method Comparison](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#6-method-comparison)
#   - [7. Save enriched data](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#7-save-enriched-data)
# - **[2.6 Event Based](Descriptive/2_bluesky/2.6_event_based.ipynb)**
#     - [1 · Top TF-IDF Term Shifts per Event](Descriptive/2_bluesky/2.6_event_based.ipynb#1-top-tf-idf-term-shifts-per-event)
#     - [2 · Buzz-Group Composition Shift](Descriptive/2_bluesky/2.6_event_based.ipynb#2-buzz-group-composition-shift)
#     - [3 · Daily Post Volume & Buzz-Group Stacked Area](Descriptive/2_bluesky/2.6_event_based.ipynb#3-daily-post-volume-buzz-group-stacked-area)
#   - [2) Event-Based  NLP](Descriptive/2_bluesky/2.6_event_based.ipynb#2-event-based-nlp)
#   - [3) Event-Based Sentiment Analysis](Descriptive/2_bluesky/2.6_event_based.ipynb#3-event-based-sentiment-analysis)
#
# ### 3_newspapers
#
# - **[3.1 Eda](Descriptive/3_newspapers/3.1_eda.ipynb)**
#   - [1. Load MediaCloud Stories](Descriptive/3_newspapers/3.1_eda.ipynb#1-load-mediacloud-stories)
#   - [2. Assign Political Leaning to MediaCloud Sources](Descriptive/3_newspapers/3.1_eda.ipynb#2-assign-political-leaning-to-mediacloud-sources)
#   - [3. Standardise Columns](Descriptive/3_newspapers/3.1_eda.ipynb#3-standardise-columns)
#   - [4. Sort & Inspect](Descriptive/3_newspapers/3.1_eda.ipynb#4-sort-inspect)
#   - [4b. Clean Source Names](Descriptive/3_newspapers/3.1_eda.ipynb#4b-clean-source-names)
#   - [4c. Text Preprocessing](Descriptive/3_newspapers/3.1_eda.ipynb#4c-text-preprocessing)
#   - [5. Save to Silver Layer](Descriptive/3_newspapers/3.1_eda.ipynb#5-save-to-silver-layer)
#   - [6. Quick Overview](Descriptive/3_newspapers/3.1_eda.ipynb#6-quick-overview)
# - **[3.2 Textual Analysis](Descriptive/3_newspapers/3.2_textual_analysis.ipynb)**
#   - [1. Text Preprocessing](Descriptive/3_newspapers/3.2_textual_analysis.ipynb#1-text-preprocessing)
#   - [2. Word Clouds](Descriptive/3_newspapers/3.2_textual_analysis.ipynb#2-word-clouds)
#   - [3. TF-IDF Analysis Most Distinctive Words per Leaning](Descriptive/3_newspapers/3.2_textual_analysis.ipynb#3-tf-idf-analysis-most-distinctive-words-per-leaning)
#   - [4. SVD / Latent Semantic Analysis (LSA)](Descriptive/3_newspapers/3.2_textual_analysis.ipynb#4-svd-latent-semantic-analysis-lsa)
#   - [5. Word Co-occurrence Networks](Descriptive/3_newspapers/3.2_textual_analysis.ipynb#5-word-co-occurrence-networks)
#   - [6. Key Term Frequency Over Time](Descriptive/3_newspapers/3.2_textual_analysis.ipynb#6-key-term-frequency-over-time)
# - **[3.3 Nlp](Descriptive/3_newspapers/3.3_nlp.ipynb)**
#   - [1. POS Tagging](Descriptive/3_newspapers/3.3_nlp.ipynb#1-pos-tagging)
#   - [2. Named Entity Recognition (NER)](Descriptive/3_newspapers/3.3_nlp.ipynb#2-named-entity-recognition-ner)
#   - [3. Word Embeddings Word2Vec (Trump-focused)](Descriptive/3_newspapers/3.3_nlp.ipynb#3-word-embeddings-word2vec-trump-focused)
#     - [3b. Trump Sentiment Score via Embedding Projection](Descriptive/3_newspapers/3.3_nlp.ipynb#3b-trump-sentiment-score-via-embedding-projection)
#   - [4. Word Embeddings GloVe (pre-trained)](Descriptive/3_newspapers/3.3_nlp.ipynb#4-word-embeddings-glove-pre-trained)
#   - [5. Dimensionality Reduction t-SNE & UMAP](Descriptive/3_newspapers/3.3_nlp.ipynb#5-dimensionality-reduction-t-sne-umap)
#   - [6. Topic Modelling LDA](Descriptive/3_newspapers/3.3_nlp.ipynb#6-topic-modelling-lda)
#   - [7. Basetable Features](Descriptive/3_newspapers/3.3_nlp.ipynb#7-basetable-features)
# - **[3.4 Analysis](Descriptive/3_newspapers/3.4_analysis.ipynb)**
#   - [1. Load & inspect](Descriptive/3_newspapers/3.4_analysis.ipynb#1-load-inspect)
#   - [2. VADER Sentiment Analysis](Descriptive/3_newspapers/3.4_analysis.ipynb#2-vader-sentiment-analysis)
#   - [3. NRCLex Emotion Analysis](Descriptive/3_newspapers/3.4_analysis.ipynb#3-nrclex-emotion-analysis)
#   - [5. Feature Engineering & Export](Descriptive/3_newspapers/3.4_analysis.ipynb#5-feature-engineering-export)
#
# ### 4_financials
#
# - **[4.1 Eda](Descriptive/4_financials/4.1_eda.ipynb)**
#   - [1 General](Descriptive/4_financials/4.1_eda.ipynb#1-general)
#     - [1.1 Data Overview](Descriptive/4_financials/4.1_eda.ipynb#11-data-overview)
#     - [1.2 Market Indicators Over Time](Descriptive/4_financials/4.1_eda.ipynb#12-market-indicators-over-time)
#     - [1.3 Correlation Between Market Indicators](Descriptive/4_financials/4.1_eda.ipynb#13-correlation-between-market-indicators)
#     - [1.4 S&P 500 vs. Market Volatility (VIX)](Descriptive/4_financials/4.1_eda.ipynb#14-sp-500-vs-market-volatility-vix)
#     - [1.5 Macroeconomic Indicators](Descriptive/4_financials/4.1_eda.ipynb#15-macroeconomic-indicators)
#   - [2 Events](Descriptive/4_financials/4.1_eda.ipynb#2-events)
#     - [2.1 Market Reaction Around Each Event](Descriptive/4_financials/4.1_eda.ipynb#21-market-reaction-around-each-event)
#     - [2.2 Indexed Performance Around Events](Descriptive/4_financials/4.1_eda.ipynb#22-indexed-performance-around-events)
#     - [2.3 Market Impact Summary](Descriptive/4_financials/4.1_eda.ipynb#23-market-impact-summary)
#
# ### 5_google_trends
#
# - **[5.1 Eda](Descriptive/5_google_trends/5.1_eda.ipynb)**
#   - [1. Load & inspect](Descriptive/5_google_trends/5.1_eda.ipynb#1-load-inspect)
#   - [2. All keywords over time](Descriptive/5_google_trends/5.1_eda.ipynb#2-all-keywords-over-time)
#   - [3. Candidate comparison with key event annotations](Descriptive/5_google_trends/5.1_eda.ipynb#3-candidate-comparison-with-key-event-annotations)
#   - [4. Trump–Harris search gap (daily difference)](Descriptive/5_google_trends/5.1_eda.ipynb#4-trumpharris-search-gap-daily-difference)
#   - [5. Smoothed trends 7-day rolling average](Descriptive/5_google_trends/5.1_eda.ipynb#5-smoothed-trends-7-day-rolling-average)
#   - [6. Interest by US state top states per candidate](Descriptive/5_google_trends/5.1_eda.ipynb#6-interest-by-us-state-top-states-per-candidate)
#   - [7. Rising related queries Trump vs Harris](Descriptive/5_google_trends/5.1_eda.ipynb#7-rising-related-queries-trump-vs-harris)
#   - [8. Correlation with Polymarket odds](Descriptive/5_google_trends/5.1_eda.ipynb#8-correlation-with-polymarket-odds)
#   - [Summary](Descriptive/5_google_trends/5.1_eda.ipynb#summary)
# - **[5.2 State Analysis](Descriptive/5_google_trends/5.2_state_analysis.ipynb)**
#   - [1. Load & overview](Descriptive/5_google_trends/5.2_state_analysis.ipynb#1-load-overview)
#   - [3. Search gap ranking Trump minus Kamala](Descriptive/5_google_trends/5.2_state_analysis.ipynb#3-search-gap-ranking-trump-minus-kamala)
#   - [4. Swing state focus](Descriptive/5_google_trends/5.2_state_analysis.ipynb#4-swing-state-focus)
#   - [5. Home state effects Walz & Vance](Descriptive/5_google_trends/5.2_state_analysis.ipynb#5-home-state-effects-walz-vance)
#   - [6. `vote` search interest by state](Descriptive/5_google_trends/5.2_state_analysis.ipynb#6-vote-search-interest-by-state)
#   - [8. Correlation heatmap across all keywords](Descriptive/5_google_trends/5.2_state_analysis.ipynb#8-correlation-heatmap-across-all-keywords)
#   - [Summary](Descriptive/5_google_trends/5.2_state_analysis.ipynb#summary)
#   - [7. `trump` search interest over time all states (heatmap)](Descriptive/5_google_trends/5.2_state_analysis.ipynb#7-trump-search-interest-over-time-all-states-heatmap)
#
# ### 6_polls
#
# - **[6.1 Eda](Descriptive/6_polls/6.1_eda.ipynb)**
#   - [Rolling Average Over Time](Descriptive/6_polls/6.1_eda.ipynb#rolling-average-over-time)
#   - [Margin Over Time](Descriptive/6_polls/6.1_eda.ipynb#margin-over-time)
#   - [Distribution](Descriptive/6_polls/6.1_eda.ipynb#distribution)
#   - [Monthly Averages](Descriptive/6_polls/6.1_eda.ipynb#monthly-averages)
#   - [Pollster Bias](Descriptive/6_polls/6.1_eda.ipynb#pollster-bias)
#   - [Summary](Descriptive/6_polls/6.1_eda.ipynb#summary)
#
# ### 7_cross_source
#
# - **[7.1 Eda](Descriptive/7_cross_source/7.1_eda.ipynb)**
#   - [1. Load & merge all data sources](Descriptive/7_cross_source/7.1_eda.ipynb#1-load-merge-all-data-sources)
#   - [2. Media Attention × Polymarket Odds](Descriptive/7_cross_source/7.1_eda.ipynb#2-media-attention-polymarket-odds)
#       - [Key Takeaways Media Attention × Polymarket Odds](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-media-attention-polymarket-odds)
#   - [3. Newspaper Sentiment × Polymarket Odds](Descriptive/7_cross_source/7.1_eda.ipynb#3-newspaper-sentiment-polymarket-odds)
#       - [Key Takeaways Newspaper Sentiment × Polymarket Odds](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-newspaper-sentiment-polymarket-odds)
#   - [4. Newspaper Emotions × Financial Markets](Descriptive/7_cross_source/7.1_eda.ipynb#4-newspaper-emotions-financial-markets)
#       - [Key Takeaways Newspaper Emotions × Financial Markets](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-newspaper-emotions-financial-markets)
#   - [5. Polls × Newspaper Coverage & Sentiment](Descriptive/7_cross_source/7.1_eda.ipynb#5-polls-newspaper-coverage-sentiment)
#       - [Key Takeaways Polls × Newspaper Coverage & Sentiment](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-polls-newspaper-coverage-sentiment)
#   - [6. Correlation Overview](Descriptive/7_cross_source/7.1_eda.ipynb#6-correlation-overview)
#       - [Key Takeaways Correlation Overview](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-correlation-overview)
#   - [7. Key-Events Timeline All Signals at a Glance](Descriptive/7_cross_source/7.1_eda.ipynb#7-key-events-timeline-all-signals-at-a-glance)
#       - [Key Takeaways Key-Events Timeline (All Signals at a Glance)](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-key-events-timeline-all-signals-at-a-glance)
#   - [8. Google Trends × Cross-Source Signals](Descriptive/7_cross_source/7.1_eda.ipynb#8-google-trends-cross-source-signals)
#       - [Key Takeaways Google Trends × Cross-Source Signals](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-google-trends-cross-source-signals)
#
# ## Predictive
#
# - **[Basetable](Predictive/basetable.ipynb)**
#     - [Variable Overview](Predictive/basetable.ipynb#variable-overview)
#   - [1. Time Dimension](Predictive/basetable.ipynb#1-time-dimension)
#   - [2. Bluesky](Predictive/basetable.ipynb#2-bluesky)
#     - [General](Predictive/basetable.ipynb#general)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#     - [Network](Predictive/basetable.ipynb#network)
#   - [3. Reddit](Predictive/basetable.ipynb#3-reddit)
#     - [General](Predictive/basetable.ipynb#general)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#   - [4. Newspapers](Predictive/basetable.ipynb#4-newspapers)
#     - [Volume & Attention](Predictive/basetable.ipynb#volume-attention)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#     - [Topics](Predictive/basetable.ipynb#topics)
#   - [5. Financials](Predictive/basetable.ipynb#5-financials)
#     - [Market data (daily)](Predictive/basetable.ipynb#market-data-daily)
#     - [Macro data (monthly)](Predictive/basetable.ipynb#macro-data-monthly)
#   - [6. Political Data](Predictive/basetable.ipynb#6-political-data)
#     - [Events](Predictive/basetable.ipynb#events)
#     - [Polls](Predictive/basetable.ipynb#polls)
#   - [7. Lag Features (t-1)](Predictive/basetable.ipynb#7-lag-features-t-1)
# - **[Basetable V2](Predictive/basetable_v2.ipynb)**
#     - [Variable Overview](Predictive/basetable_v2.ipynb#variable-overview)
#   - [1. Time Dimension](Predictive/basetable_v2.ipynb#1-time-dimension)
#   - [2. Bluesky](Predictive/basetable_v2.ipynb#2-bluesky)
#     - [General](Predictive/basetable_v2.ipynb#general)
#     - [Sentiment](Predictive/basetable_v2.ipynb#sentiment)
#     - [Network](Predictive/basetable_v2.ipynb#network)
#   - [3. Reddit](Predictive/basetable_v2.ipynb#3-reddit)
#     - [General](Predictive/basetable_v2.ipynb#general)
#     - [Sentiment](Predictive/basetable_v2.ipynb#sentiment)
#   - [4. Newspapers](Predictive/basetable_v2.ipynb#4-newspapers)
#     - [Volume & Attention](Predictive/basetable_v2.ipynb#volume-attention)
#     - [Sentiment](Predictive/basetable_v2.ipynb#sentiment)
#     - [Emotions (NRCLex)](Predictive/basetable_v2.ipynb#emotions-nrclex)
#     - [Topics](Predictive/basetable_v2.ipynb#topics)
#     - [Sentiment Velocity](Predictive/basetable_v2.ipynb#sentiment-velocity)
#   - [5. Financials](Predictive/basetable_v2.ipynb#5-financials)
#     - [Market data (daily)](Predictive/basetable_v2.ipynb#market-data-daily)
#     - [Macro data (monthly)](Predictive/basetable_v2.ipynb#macro-data-monthly)
#   - [6. Political Data](Predictive/basetable_v2.ipynb#6-political-data)
#     - [Events](Predictive/basetable_v2.ipynb#events)
#     - [Polls](Predictive/basetable_v2.ipynb#polls)
#   - [7. Lag Features (t-1)](Predictive/basetable_v2.ipynb#7-lag-features-t-1)
# - **[Modela](Predictive/modelA.ipynb)**
#   - [2024 US Presidential Election Walk-Forward Machine Learning](Predictive/modelA.ipynb#2024-us-presidential-election-walk-forward-machine-learning)
#   - [1. Setup](Predictive/modelA.ipynb#1-setup)
#   - [2. Data Loading & Feature Groups](Predictive/modelA.ipynb#2-data-loading-feature-groups)
#   - [3. Walk-Forward CV Splits](Predictive/modelA.ipynb#3-walk-forward-cv-splits)
#     - [Why walk-forward (not k-fold)?](Predictive/modelA.ipynb#why-walk-forward-not-k-fold)
#     - [No fit-transform leakage](Predictive/modelA.ipynb#no-fit-transform-leakage)
#   - [4. Preprocessing Pipeline (No Leakage)](Predictive/modelA.ipynb#4-preprocessing-pipeline-no-leakage)
#   - [5. Hyperparameter Tuning](Predictive/modelA.ipynb#5-hyperparameter-tuning)
#   - [6. Tuning Results](Predictive/modelA.ipynb#6-tuning-results)
#   - [7. Walk-Forward CV Evaluation](Predictive/modelA.ipynb#7-walk-forward-cv-evaluation)
#   - [8. Results](Predictive/modelA.ipynb#8-results)
#   - [9. Predictions vs Actual Best Model](Predictive/modelA.ipynb#9-predictions-vs-actual-best-model)
#   - [10. Feature Importance](Predictive/modelA.ipynb#10-feature-importance)
#   - [Feature Relevance Model-free Correlation with Price Level](Predictive/modelA.ipynb#feature-relevance-model-free-correlation-with-price-level)
#   - [11. Final Test Set Evaluation](Predictive/modelA.ipynb#11-final-test-set-evaluation)
# - **[Modelb](Predictive/modelB.ipynb)**
#   - [2024 US Presidential Election Walk-Forward Machine Learning](Predictive/modelB.ipynb#2024-us-presidential-election-walk-forward-machine-learning)
#   - [1. Setup](Predictive/modelB.ipynb#1-setup)
#   - [2. Data Loading](Predictive/modelB.ipynb#2-data-loading)
#   - [3. Feature Engineering](Predictive/modelB.ipynb#3-feature-engineering)
#   - [4. Target: Daily Price Change](Predictive/modelB.ipynb#4-target-daily-price-change)
#   - [5. Feature Groups](Predictive/modelB.ipynb#5-feature-groups)
#   - [6. Walk-Forward CV Splits](Predictive/modelB.ipynb#6-walk-forward-cv-splits)
#   - [7. Preprocessing Pipeline](Predictive/modelB.ipynb#7-preprocessing-pipeline)
#   - [8. Hyperparameter Tuning](Predictive/modelB.ipynb#8-hyperparameter-tuning)
#   - [9. Cross-Validation Results](Predictive/modelB.ipynb#9-cross-validation-results)
#   - [Key Finding: Market Efficiency Evidence](Predictive/modelB.ipynb#key-finding-market-efficiency-evidence)
#   - [10. Results](Predictive/modelB.ipynb#10-results)
#   - [11. Predictions vs Actual](Predictive/modelB.ipynb#11-predictions-vs-actual)
#   - [12. Feature Importance](Predictive/modelB.ipynb#12-feature-importance)
#   - [Feature Relevance Model-free Correlation with Target](Predictive/modelB.ipynb#feature-relevance-model-free-correlation-with-target)
#   - [13. Held-Out Test Set Evaluation](Predictive/modelB.ipynb#13-held-out-test-set-evaluation)
#   - [14. Summary & Market Efficiency](Predictive/modelB.ipynb#14-summary-market-efficiency)
# - **[Text Features](Predictive/text_features.ipynb)**
#   - [Why save raw text instead of pre-computed TF-IDF?](Predictive/text_features.ipynb#why-save-raw-text-instead-of-pre-computed-tf-idf)
#   - [Setup](Predictive/text_features.ipynb#setup)
#   - [Load & align on basetable dates](Predictive/text_features.ipynb#load-align-on-basetable-dates)
#   - [Quick vocabulary check](Predictive/text_features.ipynb#quick-vocabulary-check)
#   - [Save](Predictive/text_features.ipynb#save)
#
# ### Basic
#
# - **[1 Lag](Predictive/Basic/1_lag.ipynb)**
#   - [1. Setup](Predictive/Basic/1_lag.ipynb#1-setup)
#   - [2. Load data, create lag features & target](Predictive/Basic/1_lag.ipynb#2-load-data-create-lag-features-target)
#   - [3. Train/val/test split](Predictive/Basic/1_lag.ipynb#3-trainvaltest-split)
#   - [4. CV folds](Predictive/Basic/1_lag.ipynb#4-cv-folds)
#   - [5. Helper functions](Predictive/Basic/1_lag.ipynb#5-helper-functions)
#   - [6. Model 1 Linear Regression](Predictive/Basic/1_lag.ipynb#6-model-1-linear-regression)
#   - [7. Model 2 Random Forest](Predictive/Basic/1_lag.ipynb#7-model-2-random-forest)
#   - [8. Model 3 Neural Network (MLP)](Predictive/Basic/1_lag.ipynb#8-model-3-neural-network-mlp)
#   - [9. Model comparison](Predictive/Basic/1_lag.ipynb#9-model-comparison)
# - **[2 Social Media](Predictive/Basic/2_social_media.ipynb)**
#   - [1. Setup](Predictive/Basic/2_social_media.ipynb#1-setup)
#   - [2. Load data & compute target](Predictive/Basic/2_social_media.ipynb#2-load-data-compute-target)
#   - [3. Train/val/test split](Predictive/Basic/2_social_media.ipynb#3-trainvaltest-split)
#   - [4. CV folds](Predictive/Basic/2_social_media.ipynb#4-cv-folds)
#   - [5. Helper functions](Predictive/Basic/2_social_media.ipynb#5-helper-functions)
#   - [6. Model 1 -- Linear Regression](Predictive/Basic/2_social_media.ipynb#6-model-1----linear-regression)
#   - [7. Model 2 -- Random Forest](Predictive/Basic/2_social_media.ipynb#7-model-2----random-forest)
#   - [8. Model 3 -- Neural Network (MLP)](Predictive/Basic/2_social_media.ipynb#8-model-3----neural-network-mlp)
#   - [9. Model comparison](Predictive/Basic/2_social_media.ipynb#9-model-comparison)
# - **[3 Web](Predictive/Basic/3_web.ipynb)**
#   - [1. Setup](Predictive/Basic/3_web.ipynb#1-setup)
#   - [2. Load data & compute target](Predictive/Basic/3_web.ipynb#2-load-data-compute-target)
#   - [3. Train/val/test split](Predictive/Basic/3_web.ipynb#3-trainvaltest-split)
#   - [4. CV folds](Predictive/Basic/3_web.ipynb#4-cv-folds)
#   - [5. Helper functions](Predictive/Basic/3_web.ipynb#5-helper-functions)
#   - [6. Model 1 Linear Regression](Predictive/Basic/3_web.ipynb#6-model-1-linear-regression)
#   - [7. Model 2 Random Forest](Predictive/Basic/3_web.ipynb#7-model-2-random-forest)
#   - [8. Model 3 Neural Network (MLP)](Predictive/Basic/3_web.ipynb#8-model-3-neural-network-mlp)
#   - [9. Model comparison](Predictive/Basic/3_web.ipynb#9-model-comparison)
# - **[4 Traditional Media](Predictive/Basic/4_traditional_media.ipynb)**
#   - [1. Setup](Predictive/Basic/4_traditional_media.ipynb#1-setup)
#   - [2. Load data & compute target](Predictive/Basic/4_traditional_media.ipynb#2-load-data-compute-target)
#   - [3. Train/val/test split](Predictive/Basic/4_traditional_media.ipynb#3-trainvaltest-split)
#   - [4. CV folds](Predictive/Basic/4_traditional_media.ipynb#4-cv-folds)
#   - [5. Helper functions](Predictive/Basic/4_traditional_media.ipynb#5-helper-functions)
#   - [6. Model 1 Linear Regression](Predictive/Basic/4_traditional_media.ipynb#6-model-1-linear-regression)
#   - [7. Model 2 Random Forest](Predictive/Basic/4_traditional_media.ipynb#7-model-2-random-forest)
#   - [8. Model 3 Neural Network (MLP)](Predictive/Basic/4_traditional_media.ipynb#8-model-3-neural-network-mlp)
#   - [9. Model comparison](Predictive/Basic/4_traditional_media.ipynb#9-model-comparison)
# - **[5 Financial](Predictive/Basic/5_financial.ipynb)**
#   - [1. Setup](Predictive/Basic/5_financial.ipynb#1-setup)
#   - [2. Load data & compute target](Predictive/Basic/5_financial.ipynb#2-load-data-compute-target)
#   - [3. Train/val/test split](Predictive/Basic/5_financial.ipynb#3-trainvaltest-split)
#   - [4. CV folds](Predictive/Basic/5_financial.ipynb#4-cv-folds)
#   - [5. Helper functions](Predictive/Basic/5_financial.ipynb#5-helper-functions)
#   - [6. Model 1 Linear Regression](Predictive/Basic/5_financial.ipynb#6-model-1-linear-regression)
#   - [7. Model 2 Random Forest](Predictive/Basic/5_financial.ipynb#7-model-2-random-forest)
#   - [8. Model 3 Neural Network (MLP)](Predictive/Basic/5_financial.ipynb#8-model-3-neural-network-mlp)
#   - [9. Model comparison](Predictive/Basic/5_financial.ipynb#9-model-comparison)
