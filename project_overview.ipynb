# %% [markdown]
# # Project Overview
#
# ## Descriptive
#
# ### 1_Reddit
#
# - **[1.1 Preprocessing](Descriptive/1_Reddit/1.1_Preprocessing.ipynb)**
#   - [1. Helper functions](Descriptive/1_Reddit/1.1_Preprocessing.ipynb#1-helper-functions)
#   - [2. Load & combine all comments](Descriptive/1_Reddit/1.1_Preprocessing.ipynb#2-load-combine-all-comments)
#   - [3. Load posts](Descriptive/1_Reddit/1.1_Preprocessing.ipynb#3-load-posts)
#   - [4. Quick check](Descriptive/1_Reddit/1.1_Preprocessing.ipynb#4-quick-check)
# - **[1.2 Network Analysis](Descriptive/1_Reddit/1.2_Network_analysis.ipynb)**
#   - [1. User-user Reply Network](Descriptive/1_Reddit/1.2_Network_analysis.ipynb#1-user-user-reply-network)
#   - [2. Author Activity — Cross-subreddit Overlap](Descriptive/1_Reddit/1.2_Network_analysis.ipynb#2-author-activity-cross-subreddit-overlap)
#   - [3. Post-Comment Bipartite Network — Engagement](Descriptive/1_Reddit/1.2_Network_analysis.ipynb#3-post-comment-bipartite-network-engagement)
# - **[1.3 Textual Analysis](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb)**
#       - [Politics posts](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#politics-posts)
#       - [Worldnews posts](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#worldnews-posts)
#       - [Conservative posts](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#conservative-posts)
#       - [Conservative comments](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#conservative-comments)
#     - [Concatenate all posts](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#concatenate-all-posts)
#   - [Descriptive setup (no train test split)](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#descriptive-setup-no-train-test-split)
#         - [Analyzing Review Length Distribution](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#analyzing-review-length-distribution)
#         - [Word Count Distribution](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#word-count-distribution)
#       - [Basic Preprocessing steps](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#basic-preprocessing-steps)
#         - [Before vs. After Comparison](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#before-vs-after-comparison)
#         - [Creating the Document-Term Matrix with TF-IDF](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#creating-the-document-term-matrix-with-tf-idf)
#       - [SVD](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#svd)
#         - [Interpreting Latent Concepts](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#interpreting-latent-concepts)
#         - [Explained Variance](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#explained-variance)
#   - [predictive setup --> create basetable for concatenation and feature engineering (train test split)](Descriptive/1_Reddit/1.3_Textual_analysis.ipynb#predictive-setup----create-basetable-for-concatenation-and-feature-engineering-train-test-split)
# - **[1.4 Wordclouds](Descriptive/1_Reddit/1.4_Wordclouds.ipynb)**
#   - [1. Wordclouds Comments — per Subreddit](Descriptive/1_Reddit/1.4_Wordclouds.ipynb#1-wordclouds-comments-per-subreddit)
#   - [2. Wordclouds Post-titels — per Subreddit](Descriptive/1_Reddit/1.4_Wordclouds.ipynb#2-wordclouds-post-titels-per-subreddit)
#   - [3. Per-Candidate Wordclouds](Descriptive/1_Reddit/1.4_Wordclouds.ipynb#3-per-candidate-wordclouds)
#   - [4. TF-IDF — Characteristic Words per Subreddit](Descriptive/1_Reddit/1.4_Wordclouds.ipynb#4-tf-idf-characteristic-words-per-subreddit)
# - **[1.5 Sentiment Analysis](Descriptive/1_Reddit/1.5_Sentiment_analysis.ipynb)**
#   - [1. Sentiment Time Series per Subreddit](Descriptive/1_Reddit/1.5_Sentiment_analysis.ipynb#1-sentiment-time-series-per-subreddit)
#   - [2. Candidate Sentiment per Subreddit](Descriptive/1_Reddit/1.5_Sentiment_analysis.ipynb#2-candidate-sentiment-per-subreddit)
#   - [3. Polarisation Metrics](Descriptive/1_Reddit/1.5_Sentiment_analysis.ipynb#3-polarisation-metrics)
#
# ### 2_Bluesky
#
# - **[2.1 Network Analysis](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb)**
#     - [Framing: buzz clusters, not supporter groups](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#framing-buzz-clusters-not-supporter-groups)
#   - [1 · Setup](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#1-setup)
#   - [2 · Data](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#2-data)
#   - [3 · Network Construction](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#3-network-construction)
#   - [4 · Network Structure & Statistics](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#4-network-structure-statistics)
#   - [5 · Degree Distribution](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#5-degree-distribution)
#     - [Insight — Power-law degree distribution](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#insight-power-law-degree-distribution)
#   - [6 · Centrality Analysis](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#6-centrality-analysis)
#     - [Insight — Who dominates the conversation?](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#insight-who-dominates-the-conversation)
#     - [Insight — Four types of accounts in the mention landscape](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#insight-four-types-of-accounts-in-the-mention-landscape)
#   - [7 · Echo Chamber Analysis](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#7-echo-chamber-analysis)
#     - [Insight — Hashtag spaces stay separate: a cluster bubble effect](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#insight-hashtag-spaces-stay-separate-a-cluster-bubble-effect)
#   - [8 · Network Visualisation](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#8-network-visualisation)
#     - [Insight — The topology of political conversation](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#insight-the-topology-of-political-conversation)
#   - [9 · Bridge Node Analysis](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#9-bridge-node-analysis)
#     - [Insight — Bridges vs cluster hubs: two very different types of accounts](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#insight-bridges-vs-cluster-hubs-two-very-different-types-of-accounts)
#   - [10 · Temporal Polarisation](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#10-temporal-polarisation)
#     - [Insight — Do hashtag spaces become more insular over time?](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#insight-do-hashtag-spaces-become-more-insular-over-time)
#   - [11 · Summary Dashboard](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#11-summary-dashboard)
#   - [Overall conclusions](Descriptive/2_Bluesky/2.1_Network_analysis.ipynb#overall-conclusions)
# - **[2.2 Textual Analysis](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb)**
#         - [Analyzing Review Length Distribution](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#analyzing-review-length-distribution)
#         - [Word Count Distribution](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#word-count-distribution)
#       - [Basic Preprocessing steps](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#basic-preprocessing-steps)
#         - [Before vs. After Comparison](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#before-vs-after-comparison)
#         - [Creating the Document-Term Matrix with TF-IDF](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#creating-the-document-term-matrix-with-tf-idf)
#       - [SVD](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#svd)
#         - [Interpreting Latent Concepts](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#interpreting-latent-concepts)
#         - [Explained Variance](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#explained-variance)
#   - [predictive setup --> create basetable for concatenation and feature engineering (train test split)](Descriptive/2_Bluesky/2.2_Textual_analysis.ipynb#predictive-setup----create-basetable-for-concatenation-and-feature-engineering-train-test-split)
# - [2.3 Nlp](Descriptive/2_Bluesky/2.3_NLP.ipynb)
#
# ### 3_News
#
# - **[3.1 Combining](Descriptive/3_News/3.1_Combining.ipynb)**
#   - [1. Load Both Datasets](Descriptive/3_News/3.1_Combining.ipynb#1-load-both-datasets)
#   - [2. Assign Political Leaning to MediaCloud Sources](Descriptive/3_News/3.1_Combining.ipynb#2-assign-political-leaning-to-mediacloud-sources)
#   - [3. Standardise MediaCloud to Match Scraped Columns](Descriptive/3_News/3.1_Combining.ipynb#3-standardise-mediacloud-to-match-scraped-columns)
#   - [4. Combine & Deduplicate](Descriptive/3_News/3.1_Combining.ipynb#4-combine-deduplicate)
#   - [4b. Clean Source Names](Descriptive/3_News/3.1_Combining.ipynb#4b-clean-source-names)
#   - [5. Save to Silver Layer](Descriptive/3_News/3.1_Combining.ipynb#5-save-to-silver-layer)
#   - [6. Quick Overview](Descriptive/3_News/3.1_Combining.ipynb#6-quick-overview)
# - **[3.2 Textual Analysis](Descriptive/3_News/3.2_Textual_analysis.ipynb)**
#   - [1. Text Preprocessing](Descriptive/3_News/3.2_Textual_analysis.ipynb#1-text-preprocessing)
#   - [2. Word Clouds](Descriptive/3_News/3.2_Textual_analysis.ipynb#2-word-clouds)
#   - [3. TF-IDF Analysis — Most Distinctive Words per Leaning](Descriptive/3_News/3.2_Textual_analysis.ipynb#3-tf-idf-analysis-most-distinctive-words-per-leaning)
#   - [4. SVD / Latent Semantic Analysis (LSA)](Descriptive/3_News/3.2_Textual_analysis.ipynb#4-svd-latent-semantic-analysis-lsa)
#   - [5. Word Co-occurrence Networks](Descriptive/3_News/3.2_Textual_analysis.ipynb#5-word-co-occurrence-networks)
#   - [6. Key Term Frequency Over Time](Descriptive/3_News/3.2_Textual_analysis.ipynb#6-key-term-frequency-over-time)
#   - [7. Basetable Features — Textual Analysis](Descriptive/3_News/3.2_Textual_analysis.ipynb#7-basetable-features-textual-analysis)
# - **[3.3 Nlp](Descriptive/3_News/3.3_NLP.ipynb)**
#   - [1. POS Tagging](Descriptive/3_News/3.3_NLP.ipynb#1-pos-tagging)
#   - [2. Named Entity Recognition (NER)](Descriptive/3_News/3.3_NLP.ipynb#2-named-entity-recognition-ner)
#   - [3. Word Embeddings — Word2Vec (Trump-focused)](Descriptive/3_News/3.3_NLP.ipynb#3-word-embeddings-word2vec-trump-focused)
#     - [3b. Trump Sentiment Score via Embedding Projection](Descriptive/3_News/3.3_NLP.ipynb#3b-trump-sentiment-score-via-embedding-projection)
#   - [4. Word Embeddings — GloVe (pre-trained)](Descriptive/3_News/3.3_NLP.ipynb#4-word-embeddings-glove-pre-trained)
#   - [5. Dimensionality Reduction — t-SNE & UMAP](Descriptive/3_News/3.3_NLP.ipynb#5-dimensionality-reduction-t-sne-umap)
#   - [6. Topic Modelling — LDA](Descriptive/3_News/3.3_NLP.ipynb#6-topic-modelling-lda)
#   - [7. Basetable Features](Descriptive/3_News/3.3_NLP.ipynb#7-basetable-features)
# - **[3.4 Analysis](Descriptive/3_News/3.4_Analysis.ipynb)**
#   - [── 1. Load & inspect ─────────────────────────────────────────────────────────────────](Descriptive/3_News/3.4_Analysis.ipynb#1-load-inspect)
#   - [── 2. VADER Sentiment Analysis ────────────────────────────────────────────────────](Descriptive/3_News/3.4_Analysis.ipynb#2-vader-sentiment-analysis)
#   - [── 3. NRCLex Emotion Analysis ──────────────────────────────────────────────────](Descriptive/3_News/3.4_Analysis.ipynb#3-nrclex-emotion-analysis)
#   - [── 5. Feature Engineering & Export ────────────────────────────────────────────](Descriptive/3_News/3.4_Analysis.ipynb#5-feature-engineering-export)
# - **[3.5 Cross Source](Descriptive/3_News/3.5_Cross_source.ipynb)**
#   - [── 1. Load & merge all data sources ───────────────────────────────────────────](Descriptive/3_News/3.5_Cross_source.ipynb#1-load-merge-all-data-sources)
#   - [── 2. Media Attention × Polymarket Odds ───────────────────────────────────────](Descriptive/3_News/3.5_Cross_source.ipynb#2-media-attention-polymarket-odds)
#       - [Key Takeaways — Media Attention × Polymarket Odds](Descriptive/3_News/3.5_Cross_source.ipynb#key-takeaways-media-attention-polymarket-odds)
#   - [── 3. Newspaper Sentiment × Polymarket Odds ─────────────────────────────────](Descriptive/3_News/3.5_Cross_source.ipynb#3-newspaper-sentiment-polymarket-odds)
#       - [Key Takeaways — Newspaper Sentiment × Polymarket Odds](Descriptive/3_News/3.5_Cross_source.ipynb#key-takeaways-newspaper-sentiment-polymarket-odds)
#   - [── 4. Newspaper Emotions × Financial Markets ────────────────────────────────](Descriptive/3_News/3.5_Cross_source.ipynb#4-newspaper-emotions-financial-markets)
#       - [Key Takeaways — Newspaper Emotions × Financial Markets](Descriptive/3_News/3.5_Cross_source.ipynb#key-takeaways-newspaper-emotions-financial-markets)
#   - [── 5. Polls × Newspaper Coverage & Sentiment ────────────────────────────────](Descriptive/3_News/3.5_Cross_source.ipynb#5-polls-newspaper-coverage-sentiment)
#       - [Key Takeaways — Polls × Newspaper Coverage & Sentiment](Descriptive/3_News/3.5_Cross_source.ipynb#key-takeaways-polls-newspaper-coverage-sentiment)
#   - [── 6. Correlation Overview ────────────────────────────────────────────────────](Descriptive/3_News/3.5_Cross_source.ipynb#6-correlation-overview)
#       - [Key Takeaways — Correlation Overview](Descriptive/3_News/3.5_Cross_source.ipynb#key-takeaways-correlation-overview)
#   - [── 7. Key-Events Timeline — All Signals at a Glance ─────────────────────────](Descriptive/3_News/3.5_Cross_source.ipynb#7-key-events-timeline-all-signals-at-a-glance)
#       - [Key Takeaways — Key-Events Timeline](Descriptive/3_News/3.5_Cross_source.ipynb#key-takeaways-key-events-timeline)
#
# ### 4_Financials
#
# - **[4.1 Descriptive](Descriptive/4_Financials/4.1_Descriptive.ipynb)**
#   - [1 — General](Descriptive/4_Financials/4.1_Descriptive.ipynb#1-general)
#     - [1.1 — Data Overview](Descriptive/4_Financials/4.1_Descriptive.ipynb#11-data-overview)
#     - [1.2 — Market Indicators Over Time](Descriptive/4_Financials/4.1_Descriptive.ipynb#12-market-indicators-over-time)
#     - [1.3 — Correlation Between Market Indicators](Descriptive/4_Financials/4.1_Descriptive.ipynb#13-correlation-between-market-indicators)
#     - [1.4 — S&P 500 vs. Market Volatility (VIX)](Descriptive/4_Financials/4.1_Descriptive.ipynb#14-sp-500-vs-market-volatility-vix)
#     - [1.5 — Macroeconomic Indicators](Descriptive/4_Financials/4.1_Descriptive.ipynb#15-macroeconomic-indicators)
#   - [2 — Events](Descriptive/4_Financials/4.1_Descriptive.ipynb#2-events)
#     - [2.1 — Market Reaction Around Each Event](Descriptive/4_Financials/4.1_Descriptive.ipynb#21-market-reaction-around-each-event)
#     - [2.2 — Indexed Performance Around Events](Descriptive/4_Financials/4.1_Descriptive.ipynb#22-indexed-performance-around-events)
#     - [2.3 — Market Impact Summary](Descriptive/4_Financials/4.1_Descriptive.ipynb#23-market-impact-summary)
#
# ### 5_Google Trends
#
# - **[5.1 Descriptive Analysis](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb)**
#   - [1. Load & inspect](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#1-load-inspect)
#   - [2. All keywords over time](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#2-all-keywords-over-time)
#   - [3. Candidate comparison with key event annotations](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#3-candidate-comparison-with-key-event-annotations)
#   - [4. Trump–Harris search gap (daily difference)](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#4-trumpharris-search-gap-daily-difference)
#   - [5. Smoothed trends — 7-day rolling average](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#5-smoothed-trends-7-day-rolling-average)
#   - [6. Interest by US state — top states per candidate](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#6-interest-by-us-state-top-states-per-candidate)
#   - [7. Rising related queries — Trump vs Harris](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#7-rising-related-queries-trump-vs-harris)
#   - [8. Correlation with Polymarket odds](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#8-correlation-with-polymarket-odds)
#   - [Summary](Descriptive/5_Google%20Trends/5.1_Descriptive_analysis.ipynb#summary)
# - **[5.2 State Analysis](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb)**
#   - [1. Load & overview](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb#1-load-overview)
#   - [3. Search gap ranking — Trump minus Kamala](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb#3-search-gap-ranking-trump-minus-kamala)
#   - [4. Swing state focus](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb#4-swing-state-focus)
#   - [5. Home state effects — Walz & Vance](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb#5-home-state-effects-walz-vance)
#   - [6. `vote` search interest by state](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb#6-vote-search-interest-by-state)
#   - [8. Correlation heatmap across all keywords](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb#8-correlation-heatmap-across-all-keywords)
#   - [Summary](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb#summary)
#   - [7. `trump` search interest over time — all states (heatmap)](Descriptive/5_Google%20Trends/5.2_State_analysis.ipynb#7-trump-search-interest-over-time-all-states-heatmap)
#
# ### 6_Polls
#
# - **[6.1 Descriptive Analysis](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb)**
#   - [What are polls and why do we use them?](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#what-are-polls-and-why-do-we-use-them)
#   - [What this notebook does](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#what-this-notebook-does)
#   - [0. Setup](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#0-setup)
#   - [1. Load data](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#1-load-data)
#   - [2. Overview](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#2-overview)
#   - [3. Polling averages over time](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#3-polling-averages-over-time)
#     - [3.1 7-day rolling average with event annotations](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#31-7-day-rolling-average-with-event-annotations)
#     - [3.2 Trump–Harris margin over time](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#32-trumpharris-margin-over-time)
#     - [3.3 Distribution of poll support](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#33-distribution-of-poll-support)
#     - [3.4 Monthly averages](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#34-monthly-averages)
#     - [3.5 Average margin per pollster](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#35-average-margin-per-pollster)
#   - [4. Summary](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#4-summary)
#     - [Key findings](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#key-findings)
#     - [Features for the basetable](Descriptive/6_Polls/6.1_Descriptive_analysis.ipynb#features-for-the-basetable)
#
# ## Predictive
#
# - **[Basetable](Predictive/basetable.ipynb)**
#     - [Variable Overview](Predictive/basetable.ipynb#variable-overview)
#   - [1. Time Dimension](Predictive/basetable.ipynb#1-time-dimension)
#   - [2. Bluesky](Predictive/basetable.ipynb#2-bluesky)
#     - [General](Predictive/basetable.ipynb#general)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#     - [Network](Predictive/basetable.ipynb#network)
#   - [3. Reddit](Predictive/basetable.ipynb#3-reddit)
#     - [General](Predictive/basetable.ipynb#general)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#   - [4. Newspapers](Predictive/basetable.ipynb#4-newspapers)
#     - [Volume & Attention](Predictive/basetable.ipynb#volume-attention)
#     - [Sentiment](Predictive/basetable.ipynb#sentiment)
#     - [Topics](Predictive/basetable.ipynb#topics)
#   - [5. Financials](Predictive/basetable.ipynb#5-financials)
#     - [Market data (daily)](Predictive/basetable.ipynb#market-data-daily)
#     - [Macro data (monthly)](Predictive/basetable.ipynb#macro-data-monthly)
#   - [6. Political Data](Predictive/basetable.ipynb#6-political-data)
#     - [Events](Predictive/basetable.ipynb#events)
#     - [Polls](Predictive/basetable.ipynb#polls)
#   - [7. Lag Features (t-1)](Predictive/basetable.ipynb#7-lag-features-t-1)
# - **[Modela](Predictive/modelA.ipynb)**
#   - [2024 US Presidential Election — Walk-Forward Machine Learning](Predictive/modelA.ipynb#2024-us-presidential-election-walk-forward-machine-learning)
#   - [1. Setup](Predictive/modelA.ipynb#1-setup)
#   - [2. Data Loading & Feature Groups](Predictive/modelA.ipynb#2-data-loading-feature-groups)
#   - [3. Walk-Forward CV Splits](Predictive/modelA.ipynb#3-walk-forward-cv-splits)
#     - [Why walk-forward (not k-fold)?](Predictive/modelA.ipynb#why-walk-forward-not-k-fold)
#     - [No fit-transform leakage](Predictive/modelA.ipynb#no-fit-transform-leakage)
#   - [4. Preprocessing Pipeline (No Leakage)](Predictive/modelA.ipynb#4-preprocessing-pipeline-no-leakage)
#   - [5. Hyperparameter Tuning](Predictive/modelA.ipynb#5-hyperparameter-tuning)
#   - [6. Tuning Results](Predictive/modelA.ipynb#6-tuning-results)
#   - [7. Walk-Forward CV Evaluation](Predictive/modelA.ipynb#7-walk-forward-cv-evaluation)
#   - [8. Results](Predictive/modelA.ipynb#8-results)
#   - [9. Predictions vs Actual — Best Model](Predictive/modelA.ipynb#9-predictions-vs-actual-best-model)
#   - [10. Feature Importance](Predictive/modelA.ipynb#10-feature-importance)
#   - [Feature Relevance — Model-free Correlation with Price Level](Predictive/modelA.ipynb#feature-relevance-model-free-correlation-with-price-level)
#   - [11. Final Test Set Evaluation](Predictive/modelA.ipynb#11-final-test-set-evaluation)
# - **[Modelb](Predictive/modelB.ipynb)**
#   - [2024 US Presidential Election — Walk-Forward Machine Learning](Predictive/modelB.ipynb#2024-us-presidential-election-walk-forward-machine-learning)
#   - [1. Setup](Predictive/modelB.ipynb#1-setup)
#   - [2. Data Loading](Predictive/modelB.ipynb#2-data-loading)
#   - [3. Feature Engineering](Predictive/modelB.ipynb#3-feature-engineering)
#   - [4. Target: Daily Price Change](Predictive/modelB.ipynb#4-target-daily-price-change)
#   - [5. Feature Groups](Predictive/modelB.ipynb#5-feature-groups)
#   - [6. Walk-Forward CV Splits](Predictive/modelB.ipynb#6-walk-forward-cv-splits)
#   - [7. Preprocessing Pipeline](Predictive/modelB.ipynb#7-preprocessing-pipeline)
#   - [8. Hyperparameter Tuning](Predictive/modelB.ipynb#8-hyperparameter-tuning)
#   - [9. Cross-Validation Results](Predictive/modelB.ipynb#9-cross-validation-results)
#   - [Key Finding: Market Efficiency Evidence](Predictive/modelB.ipynb#key-finding-market-efficiency-evidence)
#   - [10. Results](Predictive/modelB.ipynb#10-results)
#   - [11. Predictions vs Actual](Predictive/modelB.ipynb#11-predictions-vs-actual)
#   - [12. Feature Importance](Predictive/modelB.ipynb#12-feature-importance)
#   - [Feature Relevance — Model-free Correlation with Target](Predictive/modelB.ipynb#feature-relevance-model-free-correlation-with-target)
#   - [13. Held-Out Test Set Evaluation](Predictive/modelB.ipynb#13-held-out-test-set-evaluation)
#   - [14. Summary & Market Efficiency](Predictive/modelB.ipynb#14-summary-market-efficiency)
# - **[Text Features](Predictive/text_features.ipynb)**
#   - [Why save raw text instead of pre-computed TF-IDF?](Predictive/text_features.ipynb#why-save-raw-text-instead-of-pre-computed-tf-idf)
#   - [Setup](Predictive/text_features.ipynb#setup)
#   - [Load & align on basetable dates](Predictive/text_features.ipynb#load-align-on-basetable-dates)
#   - [Quick vocabulary check](Predictive/text_features.ipynb#quick-vocabulary-check)
#   - [Save](Predictive/text_features.ipynb#save)
#
# ## data_retrieval
#
# - **[Bluesky](data_retrieval/bluesky.ipynb)**
#   - [Bronze — bsky_US_2024_raw.csv · 32,866 rows × 14 columns](data_retrieval/bluesky.ipynb#bronze-bsky_us_2024_rawcsv-32866-rows-14-columns)
#   - [Silver — bsky_US_2024_posts.csv · 27,219 rows × 15 columns](data_retrieval/bluesky.ipynb#silver-bsky_us_2024_postscsv-27219-rows-15-columns)
# - **[Financials](data_retrieval/financials.ipynb)**
#     - [market.csv — 85 rows × 6 columns](data_retrieval/financials.ipynb#marketcsv-85-rows-6-columns)
#     - [macros.csv — 4 rows × 6 columns](data_retrieval/financials.ipynb#macroscsv-4-rows-6-columns)
#   - [Summary](data_retrieval/financials.ipynb#summary)
# - **[Google Trends](data_retrieval/google_trends.ipynb)**
#     - [trends_daily_stitched.csv — ~123 rows × 21 columns](data_retrieval/google_trends.ipynb#trends_daily_stitchedcsv-123-rows-21-columns)
#     - [trends_by_state.csv — 51 rows × 21 columns](data_retrieval/google_trends.ipynb#trends_by_statecsv-51-rows-21-columns)
#     - [trump_daily_by_state.csv](data_retrieval/google_trends.ipynb#trump_daily_by_statecsv)
#     - [related_queries_<kw>_top.csv / _rising.csv](data_retrieval/google_trends.ipynb#related_queries_kw_topcsv-_risingcsv)
#   - [1. Fetch `interest_over_time` — all keywords](data_retrieval/google_trends.ipynb#1-fetch-interest_over_time-all-keywords)
#   - [2. Fetch `interest_by_region` (US states)](data_retrieval/google_trends.ipynb#2-fetch-interest_by_region-us-states)
#   - [4. Fetch daily `trump` time series per state](data_retrieval/google_trends.ipynb#4-fetch-daily-trump-time-series-per-state)
#   - [6. Fetch `related_queries`](data_retrieval/google_trends.ipynb#6-fetch-related_queries)
#   - [Summary](data_retrieval/google_trends.ipynb#summary)
# - **[Media Cloud](data_retrieval/media_cloud.ipynb)**
#     - [mediacloud_daily.csv — 123 rows × 18 columns](data_retrieval/media_cloud.ipynb#mediacloud_dailycsv-123-rows-18-columns)
#     - [mediacloud_stories.csv — 235,191 rows × 6 columns](data_retrieval/media_cloud.ipynb#mediacloud_storiescsv-235191-rows-6-columns)
#   - [1. Dagelijkse tellingen ophalen](data_retrieval/media_cloud.ipynb#1-dagelijkse-tellingen-ophalen)
#   - [2. Feature engineering](data_retrieval/media_cloud.ipynb#2-feature-engineering)
#   - [3. Visualisatie](data_retrieval/media_cloud.ipynb#3-visualisatie)
#   - [4. Opslaan naar CSV](data_retrieval/media_cloud.ipynb#4-opslaan-naar-csv)
#   - [5. (Optioneel) Individuele artikelen ophalen voor sentimentanalyse](data_retrieval/media_cloud.ipynb#5-optioneel-individuele-artikelen-ophalen-voor-sentimentanalyse)
#   - [6. Fix: ontbrekende dagen 14–18 oktober opnieuw ophalen](data_retrieval/media_cloud.ipynb#6-fix-ontbrekende-dagen-1418-oktober-opnieuw-ophalen)
# - **[Newspapers](data_retrieval/newspapers.ipynb)**
#     - [newspaper_articles.csv — 7,684 rows × 5 columns](data_retrieval/newspapers.ipynb#newspaper_articlescsv-7684-rows-5-columns)
#   - [1. The Guardian API (Democratic-leaning)](data_retrieval/newspapers.ipynb#1-the-guardian-api-democratic-leaning)
#   - [2. New York Times Article Search API (Democratic-leaning)](data_retrieval/newspapers.ipynb#2-new-york-times-article-search-api-democratic-leaning)
#   - [3. GDELT DOC 2.0 — Fox News, Breitbart, NY Post (Republican) + NBC News (Democratic)](data_retrieval/newspapers.ipynb#3-gdelt-doc-20-fox-news-breitbart-ny-post-republican-nbc-news-democratic)
#   - [4. Combine All Sources & Save](data_retrieval/newspapers.ipynb#4-combine-all-sources-save)
# - **[Polls](data_retrieval/polls.ipynb)**
#   - [wikipedia_polls.csv — 256 rows × 6 columns](data_retrieval/polls.ipynb#wikipedia_pollscsv-256-rows-6-columns)
# - **[Polymarket](data_retrieval/polymarket.ipynb)**
#   - [polymarket_win_probabilities.csv — 124 rows × 3 columns](data_retrieval/polymarket.ipynb#polymarket_win_probabilitiescsv-124-rows-3-columns)
# - **[Reddit](data_retrieval/reddit.ipynb)**
#   - [Bronze — 14 JSONL files (comments: ~68 fields · posts: ~95 fields)](data_retrieval/reddit.ipynb#bronze-14-jsonl-files-comments-68-fields-posts-95-fields)
#   - [Silver — reddit_clean.parquet · 2,200,841 rows × 15 columns](data_retrieval/reddit.ipynb#silver-reddit_cleanparquet-2200841-rows-15-columns)
#   - [1. Setup](data_retrieval/reddit.ipynb#1-setup)
#   - [2. Remove duplicates & missing values](data_retrieval/reddit.ipynb#2-remove-duplicates-missing-values)
#   - [3. Remove deleted/removed comments](data_retrieval/reddit.ipynb#3-remove-deletedremoved-comments)
#   - [4. Text cleaning function](data_retrieval/reddit.ipynb#4-text-cleaning-function)
#   - [5. Apply cleaning](data_retrieval/reddit.ipynb#5-apply-cleaning)
#   - [6. Remove empty / low-quality comments](data_retrieval/reddit.ipynb#6-remove-empty-low-quality-comments)
#   - [7. Final clean check](data_retrieval/reddit.ipynb#7-final-clean-check)
#   - [8. Save cleaned data](data_retrieval/reddit.ipynb#8-save-cleaned-data)
