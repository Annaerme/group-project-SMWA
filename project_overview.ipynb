# %% [markdown]
# # Project Overview
#
# ## data_retrieval
#
# - **[0 Polymarket](data_retrieval/0_polymarket.ipynb)**
#   - [Setup](data_retrieval/0_polymarket.ipynb#setup)
#   - [1. Win Probabilities](data_retrieval/0_polymarket.ipynb#1-win-probabilities)
#     - [polymarket_win_probabilities.csv columns](data_retrieval/0_polymarket.ipynb#polymarket_win_probabilitiescsv-columns)
#   - [2. Trading Volume](data_retrieval/0_polymarket.ipynb#2-trading-volume)
#     - [polymarket_volume.csv columns](data_retrieval/0_polymarket.ipynb#polymarket_volumecsv-columns)
# - **[1 Reddit](data_retrieval/1_reddit.ipynb)**
#   - [Setup](data_retrieval/1_reddit.ipynb#setup)
#   - [1. Convert JSONL to Parquet](data_retrieval/1_reddit.ipynb#1-convert-jsonl-to-parquet)
#   - [2. Filter and Save](data_retrieval/1_reddit.ipynb#2-filter-and-save)
#     - [reddit_comments_filtered.parquet columns](data_retrieval/1_reddit.ipynb#reddit_comments_filteredparquet-columns)
#     - [reddit_posts_filtered.parquet columns](data_retrieval/1_reddit.ipynb#reddit_posts_filteredparquet-columns)
# - **[2 Bluesky](data_retrieval/2_bluesky.ipynb)**
#   - [Setup](data_retrieval/2_bluesky.ipynb#setup)
#   - [1. Search Parameters](data_retrieval/2_bluesky.ipynb#1-search-parameters)
#   - [2. Helper Functions](data_retrieval/2_bluesky.ipynb#2-helper-functions)
#   - [3. Collect and Save](data_retrieval/2_bluesky.ipynb#3-collect-and-save)
#     - [bsky_US_2024_raw.csv columns](data_retrieval/2_bluesky.ipynb#bsky_us_2024_rawcsv-columns)
# - **[3 Media Cloud](data_retrieval/3_media_cloud.ipynb)**
#   - [Setup](data_retrieval/3_media_cloud.ipynb#setup)
#   - [1. Daily Story Counts](data_retrieval/3_media_cloud.ipynb#1-daily-story-counts)
#     - [mediacloud_daily.csv columns](data_retrieval/3_media_cloud.ipynb#mediacloud_dailycsv-columns)
#     - [mediacloud_features.csv columns](data_retrieval/3_media_cloud.ipynb#mediacloud_featurescsv-columns)
#   - [2. Full Story Metadata](data_retrieval/3_media_cloud.ipynb#2-full-story-metadata)
#     - [mediacloud_stories.csv columns](data_retrieval/3_media_cloud.ipynb#mediacloud_storiescsv-columns)
# - **[4 Financials](data_retrieval/4_financials.ipynb)**
#   - [Setup](data_retrieval/4_financials.ipynb#setup)
#   - [1. Market Data](data_retrieval/4_financials.ipynb#1-market-data)
#     - [market.csv columns](data_retrieval/4_financials.ipynb#marketcsv-columns)
#   - [2. Macro Data](data_retrieval/4_financials.ipynb#2-macro-data)
#     - [macros.csv columns](data_retrieval/4_financials.ipynb#macroscsv-columns)
# - **[5 Google Trends](data_retrieval/5_google_trends.ipynb)**
#   - [Setup](data_retrieval/5_google_trends.ipynb#setup)
#   - [1. Daily Interest Over Time](data_retrieval/5_google_trends.ipynb#1-daily-interest-over-time)
#     - [trends_daily_stitched.csv columns](data_retrieval/5_google_trends.ipynb#trends_daily_stitchedcsv-columns)
#   - [2. Interest by Region](data_retrieval/5_google_trends.ipynb#2-interest-by-region)
#     - [trends_by_state.csv columns](data_retrieval/5_google_trends.ipynb#trends_by_statecsv-columns)
#   - [3. Daily Interest by State](data_retrieval/5_google_trends.ipynb#3-daily-interest-by-state)
#     - [trump_daily_by_state.csv columns](data_retrieval/5_google_trends.ipynb#trump_daily_by_statecsv-columns)
# - **[6 Polls](data_retrieval/6_polls.ipynb)**
#   - [Setup](data_retrieval/6_polls.ipynb#setup)
#   - [1. Fetch and Parse](data_retrieval/6_polls.ipynb#1-fetch-and-parse)
#   - [2. Clean and Standardise](data_retrieval/6_polls.ipynb#2-clean-and-standardise)
#   - [3. Save](data_retrieval/6_polls.ipynb#3-save)
#     - [wikipedia_polls.csv columns](data_retrieval/6_polls.ipynb#wikipedia_pollscsv-columns)
#
# ## Descriptive
#
# ### 0_polymarket
#
# - **[0.1 Eda](Descriptive/0_polymarket/0.1_eda.ipynb)**
#   - [Setup](Descriptive/0_polymarket/0.1_eda.ipynb#setup)
#   - [1. Win Probabilities Over Time](Descriptive/0_polymarket/0.1_eda.ipynb#1-win-probabilities-over-time)
#   - [2. Trump – Harris Spread](Descriptive/0_polymarket/0.1_eda.ipynb#2-trump-harris-spread)
#   - [3. Probability Around Key Events](Descriptive/0_polymarket/0.1_eda.ipynb#3-probability-around-key-events)
#   - [4. Event Summary Table](Descriptive/0_polymarket/0.1_eda.ipynb#4-event-summary-table)
#   - [Presentation Purposes](Descriptive/0_polymarket/0.1_eda.ipynb#presentation-purposes)
#     - [Win Probabilities — Presentation Chart](Descriptive/0_polymarket/0.1_eda.ipynb#win-probabilities-presentation-chart)
#     - [Animation Snapshots — 4 Keyframes](Descriptive/0_polymarket/0.1_eda.ipynb#animation-snapshots-4-keyframes)
#
# ### 1_reddit
#
# - **[1.1 Eda](Descriptive/1_reddit/1.1_eda.ipynb)**
#   - [Setup](Descriptive/1_reddit/1.1_eda.ipynb#setup)
#   - [1. Bronze - raw data structure](Descriptive/1_reddit/1.1_eda.ipynb#1-bronze---raw-data-structure)
#   - [2. Text preprocessing → Buzz labels → Silver](Descriptive/1_reddit/1.1_eda.ipynb#2-text-preprocessing-buzz-labels-silver)
#   - [3. Exploratory Analysis](Descriptive/1_reddit/1.1_eda.ipynb#3-exploratory-analysis)
#     - [Key counts per candidate](Descriptive/1_reddit/1.1_eda.ipynb#key-counts-per-candidate)
#     - [Posts by subreddit](Descriptive/1_reddit/1.1_eda.ipynb#posts-by-subreddit)
#     - [Daily post volume](Descriptive/1_reddit/1.1_eda.ipynb#daily-post-volume)
#     - [Score distribution (log scale)](Descriptive/1_reddit/1.1_eda.ipynb#score-distribution-log-scale)
#     - [Word count distribution](Descriptive/1_reddit/1.1_eda.ipynb#word-count-distribution)
# - **[1.2 Network Analysis](Descriptive/1_reddit/1.2_network_analysis.ipynb)**
#   - [Setup](Descriptive/1_reddit/1.2_network_analysis.ipynb#setup)
#   - [1. Subreddit Overlap Network](Descriptive/1_reddit/1.2_network_analysis.ipynb#1-subreddit-overlap-network)
#   - [2. Cross-subreddit Author Activity](Descriptive/1_reddit/1.2_network_analysis.ipynb#2-cross-subreddit-author-activity)
#   - [3. Keyword Similarity Network](Descriptive/1_reddit/1.2_network_analysis.ipynb#3-keyword-similarity-network)
#   - [4. Candidate Buzz Flow](Descriptive/1_reddit/1.2_network_analysis.ipynb#4-candidate-buzz-flow)
#   - [5. Summary & Conclusions](Descriptive/1_reddit/1.2_network_analysis.ipynb#5-summary-conclusions)
# - **[1.3 Textual Analysis](Descriptive/1_reddit/1.3_textual_analysis.ipynb)**
#   - [Setup](Descriptive/1_reddit/1.3_textual_analysis.ipynb#setup)
#   - [1. Text Length Distribution](Descriptive/1_reddit/1.3_textual_analysis.ipynb#1-text-length-distribution)
#   - [2. Preprocessing Quality Check](Descriptive/1_reddit/1.3_textual_analysis.ipynb#2-preprocessing-quality-check)
#   - [3. TF-IDF Analysis](Descriptive/1_reddit/1.3_textual_analysis.ipynb#3-tf-idf-analysis)
#   - [4. Latent Semantic Analysis (SVD)](Descriptive/1_reddit/1.3_textual_analysis.ipynb#4-latent-semantic-analysis-svd)
#   - [5. Term Frequency Over Time](Descriptive/1_reddit/1.3_textual_analysis.ipynb#5-term-frequency-over-time)
#   - [6. Word Clouds](Descriptive/1_reddit/1.3_textual_analysis.ipynb#6-word-clouds)
# - **[1.4 Nlp](Descriptive/1_reddit/1.4_nlp.ipynb)**
#   - [Setup](Descriptive/1_reddit/1.4_nlp.ipynb#setup)
#   - [1. Preprocessing](Descriptive/1_reddit/1.4_nlp.ipynb#1-preprocessing)
#   - [2. LDA Topic Modeling — Posts](Descriptive/1_reddit/1.4_nlp.ipynb#2-lda-topic-modeling-posts)
#     - [2a. Build Dictionary & Corpus](Descriptive/1_reddit/1.4_nlp.ipynb#2a-build-dictionary-corpus)
#     - [2b. Coherence Score: choosing optimal topics](Descriptive/1_reddit/1.4_nlp.ipynb#2b-coherence-score-choosing-optimal-topics)
#     - [2c. Train Final Model](Descriptive/1_reddit/1.4_nlp.ipynb#2c-train-final-model)
#     - [2d. Topic Prominence Over Time](Descriptive/1_reddit/1.4_nlp.ipynb#2d-topic-prominence-over-time)
#     - [2e. Topic Distribution per Buzz Group](Descriptive/1_reddit/1.4_nlp.ipynb#2e-topic-distribution-per-buzz-group)
#   - [3. LDA Topic Modeling — Comments](Descriptive/1_reddit/1.4_nlp.ipynb#3-lda-topic-modeling-comments)
#   - [4. Subreddit Echo Chambers](Descriptive/1_reddit/1.4_nlp.ipynb#4-subreddit-echo-chambers)
# - **[1.5 Sentiment Analysis](Descriptive/1_reddit/1.5_sentiment_analysis.ipynb)**
#   - [Setup](Descriptive/1_reddit/1.5_sentiment_analysis.ipynb#setup)
#   - [1. VADER](Descriptive/1_reddit/1.5_sentiment_analysis.ipynb#1-vader)
#   - [2. TextBlob](Descriptive/1_reddit/1.5_sentiment_analysis.ipynb#2-textblob)
#   - [3. NRCLex — Emotion Detection](Descriptive/1_reddit/1.5_sentiment_analysis.ipynb#3-nrclex-emotion-detection)
#   - [4. Method Comparison](Descriptive/1_reddit/1.5_sentiment_analysis.ipynb#4-method-comparison)
#   - [5. Save Enriched Data](Descriptive/1_reddit/1.5_sentiment_analysis.ipynb#5-save-enriched-data)
#
# ### 2_bluesky
#
# - **[2.1 Eda](Descriptive/2_bluesky/2.1_eda.ipynb)**
#   - [Setup](Descriptive/2_bluesky/2.1_eda.ipynb#setup)
#   - [1. Bronze — raw data structure](Descriptive/2_bluesky/2.1_eda.ipynb#1-bronze-raw-data-structure)
#   - [2. Text preprocessing → Buzz labels → Silver](Descriptive/2_bluesky/2.1_eda.ipynb#2-text-preprocessing-buzz-labels-silver)
#   - [3. Exploratory Analysis](Descriptive/2_bluesky/2.1_eda.ipynb#3-exploratory-analysis)
#     - [Key counts per candidate](Descriptive/2_bluesky/2.1_eda.ipynb#key-counts-per-candidate)
#     - [Like distribution (log scale)](Descriptive/2_bluesky/2.1_eda.ipynb#like-distribution-log-scale)
# - **[2.2 Network Analysis](Descriptive/2_bluesky/2.2_network_analysis.ipynb)**
#   - [Setup](Descriptive/2_bluesky/2.2_network_analysis.ipynb#setup)
#     - [Framing: buzz clusters, not supporter groups](Descriptive/2_bluesky/2.2_network_analysis.ipynb#framing-buzz-clusters-not-supporter-groups)
#   - [1. Network Construction](Descriptive/2_bluesky/2.2_network_analysis.ipynb#1-network-construction)
#   - [2. Network Structure & Statistics](Descriptive/2_bluesky/2.2_network_analysis.ipynb#2-network-structure-statistics)
#   - [3. Degree Distribution](Descriptive/2_bluesky/2.2_network_analysis.ipynb#3-degree-distribution)
#     - [Insight Power-law degree distribution](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-power-law-degree-distribution)
#   - [4. Centrality Analysis](Descriptive/2_bluesky/2.2_network_analysis.ipynb#4-centrality-analysis)
#     - [Insight Who dominates the conversation?](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-who-dominates-the-conversation)
#     - [Insight Four types of accounts in the mention landscape](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-four-types-of-accounts-in-the-mention-landscape)
#   - [5. Echo Chamber Analysis](Descriptive/2_bluesky/2.2_network_analysis.ipynb#5-echo-chamber-analysis)
#     - [Insight Hashtag spaces stay separate: a cluster bubble effect](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-hashtag-spaces-stay-separate-a-cluster-bubble-effect)
#   - [6. Network Visualisation](Descriptive/2_bluesky/2.2_network_analysis.ipynb#6-network-visualisation)
#     - [Insight The topology of political conversation](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-the-topology-of-political-conversation)
#   - [7. Bridge Node Analysis](Descriptive/2_bluesky/2.2_network_analysis.ipynb#7-bridge-node-analysis)
#     - [Insight — Who are the bridge accounts?](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-who-are-the-bridge-accounts)
#     - [Insight Bridges vs cluster hubs: two very different types of accounts](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-bridges-vs-cluster-hubs-two-very-different-types-of-accounts)
#   - [8. Temporal Polarisation](Descriptive/2_bluesky/2.2_network_analysis.ipynb#8-temporal-polarisation)
#     - [Insight Do hashtag spaces become more insular over time?](Descriptive/2_bluesky/2.2_network_analysis.ipynb#insight-do-hashtag-spaces-become-more-insular-over-time)
#   - [9. Summary & Conclusions](Descriptive/2_bluesky/2.2_network_analysis.ipynb#9-summary-conclusions)
# - **[2.3 Textual Analysis](Descriptive/2_bluesky/2.3_textual_analysis.ipynb)**
#   - [Setup](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#setup)
#   - [1. Text Length Distribution](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#1-text-length-distribution)
#     - [Analyzing Post Length Distribution](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#analyzing-post-length-distribution)
#     - [Word Count Distribution](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#word-count-distribution)
#   - [2. Preprocessing Quality Check](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#2-preprocessing-quality-check)
#       - [Preprocessing](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#preprocessing)
#     - [Before vs. After Comparison](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#before-vs-after-comparison)
#   - [3. TF-IDF Analysis](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#3-tf-idf-analysis)
#     - [Creating the Document-Term Matrix with TF-IDF](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#creating-the-document-term-matrix-with-tf-idf)
#       - [Reducing Sparsity via Spell Correction](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#reducing-sparsity-via-spell-correction)
#       - [Inspecting TF-IDF by Post Type and Buzz Group](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#inspecting-tf-idf-by-post-type-and-buzz-group)
#   - [4. SVD / Latent Semantic Analysis](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#4-svd-latent-semantic-analysis)
#     - [Singular Value Decomposition (SVD) / Latent Semantic Analysis](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#singular-value-decomposition-svd-latent-semantic-analysis)
#       - [Interpreting Latent Concepts](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#interpreting-latent-concepts)
#       - [Explained Variance](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#explained-variance)
#   - [5. Key Term Frequency Over Time](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#5-key-term-frequency-over-time)
#     - [Key Term Frequency Over Time](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#key-term-frequency-over-time)
#   - [6. Word Clouds](Descriptive/2_bluesky/2.3_textual_analysis.ipynb#6-word-clouds)
# - **[2.4 Nlp](Descriptive/2_bluesky/2.4_nlp.ipynb)**
#   - [Setup](Descriptive/2_bluesky/2.4_nlp.ipynb#setup)
#   - [1. Preprocessing](Descriptive/2_bluesky/2.4_nlp.ipynb#1-preprocessing)
#   - [2. LDA — Build Dictionary & Corpus](Descriptive/2_bluesky/2.4_nlp.ipynb#2-lda-build-dictionary-corpus)
#   - [3. LDA — Coherence Score](Descriptive/2_bluesky/2.4_nlp.ipynb#3-lda-coherence-score)
#   - [4. LDA — Train Final Model](Descriptive/2_bluesky/2.4_nlp.ipynb#4-lda-train-final-model)
#   - [5. Topic per Buzz Group](Descriptive/2_bluesky/2.4_nlp.ipynb#5-topic-per-buzz-group)
# - **[2.5 Sentiment Analysis](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb)**
#   - [Setup](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#setup)
#   - [1. VADER](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#1-vader)
#   - [2. Twitter-RoBERTa](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#2-twitter-roberta)
#   - [3. TextBlob](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#3-textblob)
#   - [4. NRCLex — Emotion Detection](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#4-nrclex-emotion-detection)
#   - [5. Method Comparison](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#5-method-comparison)
#   - [6. Save Enriched Data](Descriptive/2_bluesky/2.5_sentiment_analysis.ipynb#6-save-enriched-data)
# - **[2.6 Event Based](Descriptive/2_bluesky/2.6_event_based.ipynb)**
#     - [1 · Top TF-IDF Term Shifts per Event](Descriptive/2_bluesky/2.6_event_based.ipynb#1-top-tf-idf-term-shifts-per-event)
#     - [2 · Buzz-Group Composition Shift](Descriptive/2_bluesky/2.6_event_based.ipynb#2-buzz-group-composition-shift)
#     - [3 · Daily Post Volume & Buzz-Group Stacked Area](Descriptive/2_bluesky/2.6_event_based.ipynb#3-daily-post-volume-buzz-group-stacked-area)
#   - [2) Event-Based  NLP](Descriptive/2_bluesky/2.6_event_based.ipynb#2-event-based-nlp)
#   - [3) Event-Based Sentiment Analysis](Descriptive/2_bluesky/2.6_event_based.ipynb#3-event-based-sentiment-analysis)
#
# ### 3_newspapers
#
# - **[3.1 Eda](Descriptive/3_newspapers/3.1_eda.ipynb)**
#   - [Setup](Descriptive/3_newspapers/3.1_eda.ipynb#setup)
#   - [1. Assign Political Leaning](Descriptive/3_newspapers/3.1_eda.ipynb#1-assign-political-leaning)
#   - [2. Standardise Columns](Descriptive/3_newspapers/3.1_eda.ipynb#2-standardise-columns)
#   - [3. Sort & Inspect](Descriptive/3_newspapers/3.1_eda.ipynb#3-sort-inspect)
#     - [3a. Clean Source Names](Descriptive/3_newspapers/3.1_eda.ipynb#3a-clean-source-names)
#     - [3b. Text Preprocessing](Descriptive/3_newspapers/3.1_eda.ipynb#3b-text-preprocessing)
#   - [4. Save to Silver Layer](Descriptive/3_newspapers/3.1_eda.ipynb#4-save-to-silver-layer)
#   - [5. Quick Overview](Descriptive/3_newspapers/3.1_eda.ipynb#5-quick-overview)
# - **[3.2 Network Analysis](Descriptive/3_newspapers/3.2_network_analysis.ipynb)**
#   - [Setup](Descriptive/3_newspapers/3.2_network_analysis.ipynb#setup)
#   - [1. Source-Keyword Matrix](Descriptive/3_newspapers/3.2_network_analysis.ipynb#1-source-keyword-matrix)
#   - [2. Adjacency Matrix](Descriptive/3_newspapers/3.2_network_analysis.ipynb#2-adjacency-matrix)
#   - [3. Network Characteristics](Descriptive/3_newspapers/3.2_network_analysis.ipynb#3-network-characteristics)
#   - [4. Network Visualisation](Descriptive/3_newspapers/3.2_network_analysis.ipynb#4-network-visualisation)
#   - [5. Homophily Analysis](Descriptive/3_newspapers/3.2_network_analysis.ipynb#5-homophily-analysis)
#   - [6. Centrality](Descriptive/3_newspapers/3.2_network_analysis.ipynb#6-centrality)
# - **[3.3 Textual Analysis](Descriptive/3_newspapers/3.3_textual_analysis.ipynb)**
#   - [Setup](Descriptive/3_newspapers/3.3_textual_analysis.ipynb#setup)
#   - [1. Text Preprocessing](Descriptive/3_newspapers/3.3_textual_analysis.ipynb#1-text-preprocessing)
#   - [2. Word Clouds](Descriptive/3_newspapers/3.3_textual_analysis.ipynb#2-word-clouds)
#   - [3. TF-IDF Analysis Most Distinctive Words per Leaning](Descriptive/3_newspapers/3.3_textual_analysis.ipynb#3-tf-idf-analysis-most-distinctive-words-per-leaning)
#   - [4. SVD / Latent Semantic Analysis (LSA)](Descriptive/3_newspapers/3.3_textual_analysis.ipynb#4-svd-latent-semantic-analysis-lsa)
#   - [5. Word Co-occurrence Networks](Descriptive/3_newspapers/3.3_textual_analysis.ipynb#5-word-co-occurrence-networks)
#   - [6. Key Term Frequency Over Time](Descriptive/3_newspapers/3.3_textual_analysis.ipynb#6-key-term-frequency-over-time)
# - **[3.4 Nlp](Descriptive/3_newspapers/3.4_nlp.ipynb)**
#   - [Setup](Descriptive/3_newspapers/3.4_nlp.ipynb#setup)
#   - [1. POS Tagging](Descriptive/3_newspapers/3.4_nlp.ipynb#1-pos-tagging)
#   - [2. Named Entity Recognition (NER)](Descriptive/3_newspapers/3.4_nlp.ipynb#2-named-entity-recognition-ner)
#   - [3. Word Embeddings Word2Vec (Trump-focused)](Descriptive/3_newspapers/3.4_nlp.ipynb#3-word-embeddings-word2vec-trump-focused)
#     - [3b. Trump Sentiment Score via Embedding Projection](Descriptive/3_newspapers/3.4_nlp.ipynb#3b-trump-sentiment-score-via-embedding-projection)
#   - [4. Word Embeddings GloVe (pre-trained)](Descriptive/3_newspapers/3.4_nlp.ipynb#4-word-embeddings-glove-pre-trained)
#   - [5. Dimensionality Reduction t-SNE & UMAP](Descriptive/3_newspapers/3.4_nlp.ipynb#5-dimensionality-reduction-t-sne-umap)
#   - [6. Topic Modelling LDA](Descriptive/3_newspapers/3.4_nlp.ipynb#6-topic-modelling-lda)
# - **[3.5 Sentiment Analysis](Descriptive/3_newspapers/3.5_sentiment_analysis.ipynb)**
#   - [Setup](Descriptive/3_newspapers/3.5_sentiment_analysis.ipynb#setup)
#   - [1. VADER](Descriptive/3_newspapers/3.5_sentiment_analysis.ipynb#1-vader)
#   - [2. TextBlob](Descriptive/3_newspapers/3.5_sentiment_analysis.ipynb#2-textblob)
#   - [3. NRCLex — Emotion Detection](Descriptive/3_newspapers/3.5_sentiment_analysis.ipynb#3-nrclex-emotion-detection)
#   - [4. Method Comparison](Descriptive/3_newspapers/3.5_sentiment_analysis.ipynb#4-method-comparison)
#   - [5. Feature Engineering & Export](Descriptive/3_newspapers/3.5_sentiment_analysis.ipynb#5-feature-engineering-export)
#
# ### 4_financials
#
# - **[4.1 Eda](Descriptive/4_financials/4.1_eda.ipynb)**
#   - [Setup](Descriptive/4_financials/4.1_eda.ipynb#setup)
#   - [1. General](Descriptive/4_financials/4.1_eda.ipynb#1-general)
#     - [1.1 Data Overview](Descriptive/4_financials/4.1_eda.ipynb#11-data-overview)
#     - [1.2 Market Indicators Over Time](Descriptive/4_financials/4.1_eda.ipynb#12-market-indicators-over-time)
#     - [1.3 Correlation Between Market Indicators](Descriptive/4_financials/4.1_eda.ipynb#13-correlation-between-market-indicators)
#     - [1.4 S&P 500 vs. Market Volatility (VIX)](Descriptive/4_financials/4.1_eda.ipynb#14-sp-500-vs-market-volatility-vix)
#     - [1.5 Macroeconomic Indicators](Descriptive/4_financials/4.1_eda.ipynb#15-macroeconomic-indicators)
#   - [2. Events](Descriptive/4_financials/4.1_eda.ipynb#2-events)
#     - [2.1 Market Reaction Around Each Event](Descriptive/4_financials/4.1_eda.ipynb#21-market-reaction-around-each-event)
#     - [2.2 Indexed Performance Around Events](Descriptive/4_financials/4.1_eda.ipynb#22-indexed-performance-around-events)
#     - [2.3 Market Impact Summary](Descriptive/4_financials/4.1_eda.ipynb#23-market-impact-summary)
#
# ### 5_google_trends
#
# - **[5.1 Eda](Descriptive/5_google_trends/5.1_eda.ipynb)**
#   - [Setup](Descriptive/5_google_trends/5.1_eda.ipynb#setup)
#   - [1. All Keywords Over Time](Descriptive/5_google_trends/5.1_eda.ipynb#1-all-keywords-over-time)
#   - [2. Candidate Comparison](Descriptive/5_google_trends/5.1_eda.ipynb#2-candidate-comparison)
#   - [3. Trump–Harris Search Gap](Descriptive/5_google_trends/5.1_eda.ipynb#3-trumpharris-search-gap)
#   - [4. Smoothed Trends](Descriptive/5_google_trends/5.1_eda.ipynb#4-smoothed-trends)
#   - [5. Interest by State](Descriptive/5_google_trends/5.1_eda.ipynb#5-interest-by-state)
#   - [6. Rising Related Queries](Descriptive/5_google_trends/5.1_eda.ipynb#6-rising-related-queries)
#   - [7. Correlation with Polymarket Odds](Descriptive/5_google_trends/5.1_eda.ipynb#7-correlation-with-polymarket-odds)
# - **[5.2 State Analysis](Descriptive/5_google_trends/5.2_state_analysis.ipynb)**
#   - [Setup](Descriptive/5_google_trends/5.2_state_analysis.ipynb#setup)
#   - [1. Search Gap Ranking](Descriptive/5_google_trends/5.2_state_analysis.ipynb#1-search-gap-ranking)
#   - [2. Swing State Focus](Descriptive/5_google_trends/5.2_state_analysis.ipynb#2-swing-state-focus)
#   - [3. Home State Effects](Descriptive/5_google_trends/5.2_state_analysis.ipynb#3-home-state-effects)
#   - [4. `election 2024` Search Interest by State](Descriptive/5_google_trends/5.2_state_analysis.ipynb#4-election-2024-search-interest-by-state)
#   - [5. Correlation Heatmap](Descriptive/5_google_trends/5.2_state_analysis.ipynb#5-correlation-heatmap)
#   - [6. Trump Search Interest Heatmap](Descriptive/5_google_trends/5.2_state_analysis.ipynb#6-trump-search-interest-heatmap)
#   - [7. Animated Choropleth](Descriptive/5_google_trends/5.2_state_analysis.ipynb#7-animated-choropleth)
#
# ### 6_polls
#
# - **[6.1 Eda](Descriptive/6_polls/6.1_eda.ipynb)**
#   - [Setup](Descriptive/6_polls/6.1_eda.ipynb#setup)
#   - [1. Rolling Average Over Time](Descriptive/6_polls/6.1_eda.ipynb#1-rolling-average-over-time)
#     - [Presentation: Polls with and without Polymarket Overlay](Descriptive/6_polls/6.1_eda.ipynb#presentation-polls-with-and-without-polymarket-overlay)
#   - [2. Margin Over Time](Descriptive/6_polls/6.1_eda.ipynb#2-margin-over-time)
#   - [3. Distribution](Descriptive/6_polls/6.1_eda.ipynb#3-distribution)
#   - [4. Monthly Averages](Descriptive/6_polls/6.1_eda.ipynb#4-monthly-averages)
#   - [5. Pollster Bias](Descriptive/6_polls/6.1_eda.ipynb#5-pollster-bias)
#   - [Summary](Descriptive/6_polls/6.1_eda.ipynb#summary)
#
# ### 7_cross_source
#
# - **[7.1 Eda](Descriptive/7_cross_source/7.1_eda.ipynb)**
#   - [1. Load & merge all data sources](Descriptive/7_cross_source/7.1_eda.ipynb#1-load-merge-all-data-sources)
#   - [2. Media Attention × Polymarket Odds](Descriptive/7_cross_source/7.1_eda.ipynb#2-media-attention-polymarket-odds)
#       - [Key Takeaways Media Attention × Polymarket Odds](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-media-attention-polymarket-odds)
#   - [3. Newspaper Sentiment × Polymarket Odds](Descriptive/7_cross_source/7.1_eda.ipynb#3-newspaper-sentiment-polymarket-odds)
#       - [Key Takeaways Newspaper Sentiment × Polymarket Odds](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-newspaper-sentiment-polymarket-odds)
#   - [4. Newspaper Emotions × Financial Markets](Descriptive/7_cross_source/7.1_eda.ipynb#4-newspaper-emotions-financial-markets)
#       - [Key Takeaways Newspaper Emotions × Financial Markets](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-newspaper-emotions-financial-markets)
#   - [5. Polls × Newspaper Coverage & Sentiment](Descriptive/7_cross_source/7.1_eda.ipynb#5-polls-newspaper-coverage-sentiment)
#       - [Key Takeaways Polls × Newspaper Coverage & Sentiment](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-polls-newspaper-coverage-sentiment)
#   - [6. Correlation Overview](Descriptive/7_cross_source/7.1_eda.ipynb#6-correlation-overview)
#       - [Key Takeaways Correlation Overview](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-correlation-overview)
#   - [7. Key-Events Timeline All Signals at a Glance](Descriptive/7_cross_source/7.1_eda.ipynb#7-key-events-timeline-all-signals-at-a-glance)
#       - [Key Takeaways Key-Events Timeline (All Signals at a Glance)](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-key-events-timeline-all-signals-at-a-glance)
#   - [8. Google Trends × Cross-Source Signals](Descriptive/7_cross_source/7.1_eda.ipynb#8-google-trends-cross-source-signals)
#       - [Key Takeaways Google Trends × Cross-Source Signals](Descriptive/7_cross_source/7.1_eda.ipynb#key-takeaways-google-trends-cross-source-signals)
#   - [9. NRC 8-Emotion Profile — Full Timeline (Bluesky)](Descriptive/7_cross_source/7.1_eda.ipynb#9-nrc-8-emotion-profile-full-timeline-bluesky)
#   - [10. NRC 8-Emotion Profile — Full Timeline (News)](Descriptive/7_cross_source/7.1_eda.ipynb#10-nrc-8-emotion-profile-full-timeline-news)
#     - [General insights — sources at a glance](Descriptive/7_cross_source/7.1_eda.ipynb#general-insights-sources-at-a-glance)
# - [Tijdelijk](Descriptive/7_cross_source/tijdelijk.ipynb)
#
# ### 8_events
#
# - **[8.1 Trump Era](Descriptive/8_events/8.1_trump_era.ipynb)**
#   - [Setup](Descriptive/8_events/8.1_trump_era.ipynb#setup)
#   - [1. The Double Spike — Era Overview](Descriptive/8_events/8.1_trump_era.ipynb#1-the-double-spike-era-overview)
#   - [2. TF-IDF Term Shifts — What People Talked About](Descriptive/8_events/8.1_trump_era.ipynb#2-tf-idf-term-shifts-what-people-talked-about)
#   - [3. Sentiment Cascade — How Tone Shifted Across Platforms](Descriptive/8_events/8.1_trump_era.ipynb#3-sentiment-cascade-how-tone-shifted-across-platforms)
#   - [4. Who Was Talking — Buzz-Group Composition Shift](Descriptive/8_events/8.1_trump_era.ipynb#4-who-was-talking-buzz-group-composition-shift)
#   - [5. Google Trends — Information-Seeking Spikes](Descriptive/8_events/8.1_trump_era.ipynb#5-google-trends-information-seeking-spikes)
#   - [6. Financial Markets — The Trump Bump](Descriptive/8_events/8.1_trump_era.ipynb#6-financial-markets-the-trump-bump)
#   - [7. Cross-Source Synthesis](Descriptive/8_events/8.1_trump_era.ipynb#7-cross-source-synthesis)
#   - [8. LDA Topic Modeling — What Narratives Emerged?](Descriptive/8_events/8.1_trump_era.ipynb#8-lda-topic-modeling-what-narratives-emerged)
#   - [9. NRC Emotion Profile — Fear, Anger, Trust & Anticipation](Descriptive/8_events/8.1_trump_era.ipynb#9-nrc-emotion-profile-fear-anger-trust-anticipation)
#   - [10. Breaking News Diffusion — How July 13 Unfolded Hour by Hour](Descriptive/8_events/8.1_trump_era.ipynb#10-breaking-news-diffusion-how-july-13-unfolded-hour-by-hour)
#     - [10.1. Alternative Visualizations](Descriptive/8_events/8.1_trump_era.ipynb#101-alternative-visualizations)
#     - [10.2. Text Burst (0-6h After the Shot)](Descriptive/8_events/8.1_trump_era.ipynb#102-text-burst-0-6h-after-the-shot)
#   - [11. Partisan Newspaper Framing](Descriptive/8_events/8.1_trump_era.ipynb#11-partisan-newspaper-framing)
#   - [12. Term Co-occurrence Network — Bluesky vs Reddit](Descriptive/8_events/8.1_trump_era.ipynb#12-term-co-occurrence-network-bluesky-vs-reddit)
# - **[8.2 Biden Out Harris In](Descriptive/8_events/8.2_biden_out_harris_in.ipynb)**
#   - [Setup](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#setup)
#   - [1. Early Warning Signals — Was Biden's Exit Anticipated?](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#1-early-warning-signals-was-bidens-exit-anticipated)
#   - [2. The Attention Handoff](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#2-the-attention-handoff)
#   - [3. Prediction Market Repricing](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#3-prediction-market-repricing)
#   - [4. Social Media Volume](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#4-social-media-volume)
#     - [4b. July 21 — Hour-by-Hour Social Media Reaction](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#4b-july-21-hour-by-hour-social-media-reaction)
#     - [4c. Platform Personality — What Did Each Platform Actually Say?](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#4c-platform-personality-what-did-each-platform-actually-say)
#   - [5. Newspaper Coverage](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#5-newspaper-coverage)
#   - [6. Market Fear ≠ Political Fear](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#6-market-fear-political-fear)
#   - [7. Statistical Tests — Confirming What Moved](Descriptive/8_events/8.2_biden_out_harris_in.ipynb#7-statistical-tests-confirming-what-moved)
# - **[8.3 Debate & Trump Assassination 2.0](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb)**
#   - [Setup](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#setup)
#   - [1. The Double Spike — Era Overview](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#1-the-double-spike-era-overview)
#   - [2. TF-IDF Term Shifts — What People Talked About](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#2-tf-idf-term-shifts-what-people-talked-about)
#     - [2b. Slide version — Debate term gains (Bluesky vs Reddit)](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#2b-slide-version-debate-term-gains-bluesky-vs-reddit)
#   - [3. Who Was Talking — Buzz-Group Composition Shift](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#3-who-was-talking-buzz-group-composition-shift)
#   - [4. Polls — September as Harris's Peak Month](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#4-polls-september-as-harriss-peak-month)
#   - [5. Partisan Newspaper Framing of the Debate](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#5-partisan-newspaper-framing-of-the-debate)
#     - [5b. Newspaper Agenda-Setting — Debate vs Assassination Coverage](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#5b-newspaper-agenda-setting-debate-vs-assassination-coverage)
#   - [6. Google Trends — Transient Attention Spikes](Descriptive/8_events/8.3_debate_%26_trump_assassination_2.0.ipynb#6-google-trends-transient-attention-spikes)
# - **[8.4 Musk Mingles Copy](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb)**
#   - [Setup](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#setup)
#   - [1. Polymarket Win Probabilities](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#1-polymarket-win-probabilities)
#     - [1b. Polymarket Odds — Zoomed ±14 Days Around Each Event](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#1b-polymarket-odds-zoomed-14-days-around-each-event)
#   - [2. Volume & America PAC Mention Share — Bluesky & Reddit](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#2-volume-america-pac-mention-share-bluesky-reddit)
#   - [3. TF-IDF Term Shift — Vocabulary Change After Each Event](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#3-tf-idf-term-shift-vocabulary-change-after-each-event)
#   - [4. VADER Sentiment — Pre vs Post Each Event](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#4-vader-sentiment-pre-vs-post-each-event)
#   - [5. Musk Mention Volume by Buzz Group](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#5-musk-mention-volume-by-buzz-group)
#   - [6. NER — SpaCy Entity Analysis](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#6-ner-spacy-entity-analysis)
#   - [7. Word2Vec — Semantic Similarity Analysis](Descriptive/8_events/8.4_musk_mingles%20copy.ipynb#7-word2vec-semantic-similarity-analysis)
#
# ## Predictive
#
# ### 1_feature_engineering
#
# - **[Feature Engineering](Predictive/1_feature_engineering/feature_engineering.ipynb)**
#   - [Setup](Predictive/1_feature_engineering/feature_engineering.ipynb#setup)
#   - [1. Target — Polymarket](Predictive/1_feature_engineering/feature_engineering.ipynb#1-target-polymarket)
#   - [2. Time Dimension](Predictive/1_feature_engineering/feature_engineering.ipynb#2-time-dimension)
#   - [3. Bluesky](Predictive/1_feature_engineering/feature_engineering.ipynb#3-bluesky)
#   - [4. Reddit](Predictive/1_feature_engineering/feature_engineering.ipynb#4-reddit)
#   - [5. Networks](Predictive/1_feature_engineering/feature_engineering.ipynb#5-networks)
#   - [6. Newspapers](Predictive/1_feature_engineering/feature_engineering.ipynb#6-newspapers)
#   - [7. Google Trends](Predictive/1_feature_engineering/feature_engineering.ipynb#7-google-trends)
#   - [8. Polls](Predictive/1_feature_engineering/feature_engineering.ipynb#8-polls)
#   - [9. Financials](Predictive/1_feature_engineering/feature_engineering.ipynb#9-financials)
#   - [10. Merge](Predictive/1_feature_engineering/feature_engineering.ipynb#10-merge)
#   - [11. Lag Features](Predictive/1_feature_engineering/feature_engineering.ipynb#11-lag-features)
#   - [12. Save](Predictive/1_feature_engineering/feature_engineering.ipynb#12-save)
#
# ### 2_preprocessing
#
# - **[Preprocessing](Predictive/2_preprocessing/preprocessing.ipynb)**
#   - [Setup](Predictive/2_preprocessing/preprocessing.ipynb#setup)
#   - [1. Missing Value Imputation](Predictive/2_preprocessing/preprocessing.ipynb#1-missing-value-imputation)
#   - [2. Walk-Forward Cross-Validation Structure](Predictive/2_preprocessing/preprocessing.ipynb#2-walk-forward-cross-validation-structure)
#   - [3. Feature Selection](Predictive/2_preprocessing/preprocessing.ipynb#3-feature-selection)
#   - [4. Save Preprocessed Basetable](Predictive/2_preprocessing/preprocessing.ipynb#4-save-preprocessed-basetable)
#
# ### 4_model_analysis
#
# - **[1 Model Analysis](Predictive/4_model_analysis/1_model_analysis.ipynb)**
#   - [Setup](Predictive/4_model_analysis/1_model_analysis.ipynb#setup)
#   - [1. Test-Set Results](Predictive/4_model_analysis/1_model_analysis.ipynb#1-test-set-results)
#   - [2. Complete Results Table](Predictive/4_model_analysis/1_model_analysis.ipynb#2-complete-results-table)
#   - [3. Best Model per Feature Set](Predictive/4_model_analysis/1_model_analysis.ipynb#3-best-model-per-feature-set)
#     - [3a. MAE per Feature Set — Best Model Only](Predictive/4_model_analysis/1_model_analysis.ipynb#3a-mae-per-feature-set-best-model-only)
#     - [3b. Directional Accuracy per Feature Set — Best Model Only](Predictive/4_model_analysis/1_model_analysis.ipynb#3b-directional-accuracy-per-feature-set-best-model-only)
#   - [4. Directional Accuracy — All Models by Feature Set](Predictive/4_model_analysis/1_model_analysis.ipynb#4-directional-accuracy-all-models-by-feature-set)
#   - [5. MAE — All Models by Feature Set](Predictive/4_model_analysis/1_model_analysis.ipynb#5-mae-all-models-by-feature-set)
#   - [6. DA vs MAE — All Individual Models](Predictive/4_model_analysis/1_model_analysis.ipynb#6-da-vs-mae-all-individual-models)
#   - [7. Heatmaps — DA and MAE](Predictive/4_model_analysis/1_model_analysis.ipynb#7-heatmaps-da-and-mae)
#   - [8. R² Heatmap](Predictive/4_model_analysis/1_model_analysis.ipynb#8-r²-heatmap)
#   - [9. Overall Best Models — Top Performers by Primary Metrics](Predictive/4_model_analysis/1_model_analysis.ipynb#9-overall-best-models-top-performers-by-primary-metrics)
#   - [10. Conclusion — Overall Best Model](Predictive/4_model_analysis/1_model_analysis.ipynb#10-conclusion-overall-best-model)
# - **[2 Interpretation Shap](Predictive/4_model_analysis/2_interpretation_shap.ipynb)**
#   - [Setup](Predictive/4_model_analysis/2_interpretation_shap.ipynb#setup)
#   - [1. Retrain best models (hardcoded hyperparameters)](Predictive/4_model_analysis/2_interpretation_shap.ipynb#1-retrain-best-models-hardcoded-hyperparameters)
#   - [2. Feature Importance — XGBoost & Random Forest](Predictive/4_model_analysis/2_interpretation_shap.ipynb#2-feature-importance-xgboost-random-forest)
#   - [3. SHAP — XGBoost TreeExplainer](Predictive/4_model_analysis/2_interpretation_shap.ipynb#3-shap-xgboost-treeexplainer)
#     - [What is a SHAP value?](Predictive/4_model_analysis/2_interpretation_shap.ipynb#what-is-a-shap-value)
#     - [Why is the expected value ≈ 0?](Predictive/4_model_analysis/2_interpretation_shap.ipynb#why-is-the-expected-value-0)
#     - [Why is TreeExplainer exact?](Predictive/4_model_analysis/2_interpretation_shap.ipynb#why-is-treeexplainer-exact)
#   - [4. SHAP — SVM KernelExplainer *(overall best model)*](Predictive/4_model_analysis/2_interpretation_shap.ipynb#4-shap-svm-kernelexplainer-overall-best-model)
#     - [Why sampling?](Predictive/4_model_analysis/2_interpretation_shap.ipynb#why-sampling)
#   - [5. Cross-model SHAP comparison — SVM vs XGBoost](Predictive/4_model_analysis/2_interpretation_shap.ipynb#5-cross-model-shap-comparison-svm-vs-xgboost)
#   - [6. Ridge Regression — Standardised Coefficients](Predictive/4_model_analysis/2_interpretation_shap.ipynb#6-ridge-regression-standardised-coefficients)
#   - [7. Predictions vs Actuals — Test Period (Oct 22 – Nov 4)](Predictive/4_model_analysis/2_interpretation_shap.ipynb#7-predictions-vs-actuals-test-period-oct-22-nov-4)
#   - [8. Limitations & Honest Takeaways](Predictive/4_model_analysis/2_interpretation_shap.ipynb#8-limitations-honest-takeaways)
#     - [What the numbers actually mean](Predictive/4_model_analysis/2_interpretation_shap.ipynb#what-the-numbers-actually-mean)
#     - [The model disagreement problem (ρ = 0.041)](Predictive/4_model_analysis/2_interpretation_shap.ipynb#the-model-disagreement-problem-ρ-0041)
#     - [The test window caveat](Predictive/4_model_analysis/2_interpretation_shap.ipynb#the-test-window-caveat)
#     - [What we can trust](Predictive/4_model_analysis/2_interpretation_shap.ipynb#what-we-can-trust)
#
# ### Basic
#
# - **[1 Lag](Predictive/3_models/Basic/1_lag.ipynb)**
#   - [Setup](Predictive/3_models/Basic/1_lag.ipynb#setup)
#   - [1. Load Data & Compute Target](Predictive/3_models/Basic/1_lag.ipynb#1-load-data-compute-target)
#   - [2. Train/Val/Test Split](Predictive/3_models/Basic/1_lag.ipynb#2-trainvaltest-split)
#   - [3. CV Folds](Predictive/3_models/Basic/1_lag.ipynb#3-cv-folds)
#   - [4. Helper Functions](Predictive/3_models/Basic/1_lag.ipynb#4-helper-functions)
#   - [5. Model 1 — Ridge Regression](Predictive/3_models/Basic/1_lag.ipynb#5-model-1-ridge-regression)
#   - [6. Model 2 — Random Forest Regressor](Predictive/3_models/Basic/1_lag.ipynb#6-model-2-random-forest-regressor)
#   - [7. Model 3 — Support Vector Regression (tuned kernel)](Predictive/3_models/Basic/1_lag.ipynb#7-model-3-support-vector-regression-tuned-kernel)
#   - [8. Model 4 — XGBoost Regressor](Predictive/3_models/Basic/1_lag.ipynb#8-model-4-xgboost-regressor)
#   - [9. Naive Baseline — Always Predict Zero](Predictive/3_models/Basic/1_lag.ipynb#9-naive-baseline-always-predict-zero)
#   - [10. Model Comparison](Predictive/3_models/Basic/1_lag.ipynb#10-model-comparison)
# - **[2 Social Media](Predictive/3_models/Basic/2_social_media.ipynb)**
#   - [Setup](Predictive/3_models/Basic/2_social_media.ipynb#setup)
#   - [1. Load Data & Compute Target](Predictive/3_models/Basic/2_social_media.ipynb#1-load-data-compute-target)
#   - [2. Train/Val/Test Split](Predictive/3_models/Basic/2_social_media.ipynb#2-trainvaltest-split)
#   - [3. CV Folds](Predictive/3_models/Basic/2_social_media.ipynb#3-cv-folds)
#   - [4. Helper Functions](Predictive/3_models/Basic/2_social_media.ipynb#4-helper-functions)
#   - [5. Model 1 — Ridge Regression](Predictive/3_models/Basic/2_social_media.ipynb#5-model-1-ridge-regression)
#   - [6. Model 2 — Random Forest Regressor](Predictive/3_models/Basic/2_social_media.ipynb#6-model-2-random-forest-regressor)
#   - [7. Model 3 — Support Vector Regression (tuned kernel)](Predictive/3_models/Basic/2_social_media.ipynb#7-model-3-support-vector-regression-tuned-kernel)
#   - [8. Model 4 — XGBoost Regressor](Predictive/3_models/Basic/2_social_media.ipynb#8-model-4-xgboost-regressor)
#   - [9. Naive Baseline — Always Predict Zero](Predictive/3_models/Basic/2_social_media.ipynb#9-naive-baseline-always-predict-zero)
#   - [10. Model Comparison](Predictive/3_models/Basic/2_social_media.ipynb#10-model-comparison)
# - **[3 Web](Predictive/3_models/Basic/3_web.ipynb)**
#   - [Setup](Predictive/3_models/Basic/3_web.ipynb#setup)
#   - [1. Load Data & Compute Target](Predictive/3_models/Basic/3_web.ipynb#1-load-data-compute-target)
#   - [2. Train/Val/Test Split](Predictive/3_models/Basic/3_web.ipynb#2-trainvaltest-split)
#   - [3. CV Folds](Predictive/3_models/Basic/3_web.ipynb#3-cv-folds)
#   - [4. Helper Functions](Predictive/3_models/Basic/3_web.ipynb#4-helper-functions)
#   - [5. Model 1 — Ridge Regression](Predictive/3_models/Basic/3_web.ipynb#5-model-1-ridge-regression)
#   - [6. Model 2 — Random Forest Regressor](Predictive/3_models/Basic/3_web.ipynb#6-model-2-random-forest-regressor)
#   - [7. Model 3 — Support Vector Regression (tuned kernel)](Predictive/3_models/Basic/3_web.ipynb#7-model-3-support-vector-regression-tuned-kernel)
#   - [8. Model 4 — XGBoost Regressor](Predictive/3_models/Basic/3_web.ipynb#8-model-4-xgboost-regressor)
#   - [9. Naive Baseline — Always Predict Zero](Predictive/3_models/Basic/3_web.ipynb#9-naive-baseline-always-predict-zero)
#   - [10. Model Comparison](Predictive/3_models/Basic/3_web.ipynb#10-model-comparison)
# - **[4 Traditional Media](Predictive/3_models/Basic/4_traditional_media.ipynb)**
#   - [Setup](Predictive/3_models/Basic/4_traditional_media.ipynb#setup)
#   - [1. Load Data & Compute Target](Predictive/3_models/Basic/4_traditional_media.ipynb#1-load-data-compute-target)
#   - [2. Train/Val/Test Split](Predictive/3_models/Basic/4_traditional_media.ipynb#2-trainvaltest-split)
#   - [3. CV Folds](Predictive/3_models/Basic/4_traditional_media.ipynb#3-cv-folds)
#   - [4. Helper Functions](Predictive/3_models/Basic/4_traditional_media.ipynb#4-helper-functions)
#   - [5. Model 1 — Ridge Regression](Predictive/3_models/Basic/4_traditional_media.ipynb#5-model-1-ridge-regression)
#   - [6. Model 2 — Random Forest Regressor](Predictive/3_models/Basic/4_traditional_media.ipynb#6-model-2-random-forest-regressor)
#   - [7. Model 3 — Support Vector Regression (tuned kernel)](Predictive/3_models/Basic/4_traditional_media.ipynb#7-model-3-support-vector-regression-tuned-kernel)
#   - [8. Model 4 — XGBoost Regressor](Predictive/3_models/Basic/4_traditional_media.ipynb#8-model-4-xgboost-regressor)
#   - [9. Naive Baseline — Always Predict Zero](Predictive/3_models/Basic/4_traditional_media.ipynb#9-naive-baseline-always-predict-zero)
#   - [10. Model Comparison](Predictive/3_models/Basic/4_traditional_media.ipynb#10-model-comparison)
# - **[5 Financial](Predictive/3_models/Basic/5_financial.ipynb)**
#   - [Setup](Predictive/3_models/Basic/5_financial.ipynb#setup)
#   - [1. Load Data & Compute Target](Predictive/3_models/Basic/5_financial.ipynb#1-load-data-compute-target)
#   - [2. Train/Val/Test Split](Predictive/3_models/Basic/5_financial.ipynb#2-trainvaltest-split)
#   - [3. CV Folds](Predictive/3_models/Basic/5_financial.ipynb#3-cv-folds)
#   - [4. Helper Functions](Predictive/3_models/Basic/5_financial.ipynb#4-helper-functions)
#   - [5. Model 1 — Ridge Regression](Predictive/3_models/Basic/5_financial.ipynb#5-model-1-ridge-regression)
#   - [6. Model 2 — Random Forest Regressor](Predictive/3_models/Basic/5_financial.ipynb#6-model-2-random-forest-regressor)
#   - [7. Model 3 — Support Vector Regression (tuned kernel)](Predictive/3_models/Basic/5_financial.ipynb#7-model-3-support-vector-regression-tuned-kernel)
#   - [8. Model 4 — XGBoost Regressor](Predictive/3_models/Basic/5_financial.ipynb#8-model-4-xgboost-regressor)
#   - [9. Naive Baseline — Always Predict Zero](Predictive/3_models/Basic/5_financial.ipynb#9-naive-baseline-always-predict-zero)
#   - [10. Model Comparison](Predictive/3_models/Basic/5_financial.ipynb#10-model-comparison)
#
# ### combo
#
# - **[1 Lag Smwa](Predictive/3_models/combo/1_lag_smwa.ipynb)**
#   - [Setup](Predictive/3_models/combo/1_lag_smwa.ipynb#setup)
#   - [1. Load Data & Compute Target](Predictive/3_models/combo/1_lag_smwa.ipynb#1-load-data-compute-target)
#   - [2. Train/Val/Test Split](Predictive/3_models/combo/1_lag_smwa.ipynb#2-trainvaltest-split)
#   - [3. CV Folds](Predictive/3_models/combo/1_lag_smwa.ipynb#3-cv-folds)
#   - [4. Helper Functions](Predictive/3_models/combo/1_lag_smwa.ipynb#4-helper-functions)
#   - [5. Model 1 — Ridge Regression](Predictive/3_models/combo/1_lag_smwa.ipynb#5-model-1-ridge-regression)
#   - [6. Model 2 — Random Forest Regressor](Predictive/3_models/combo/1_lag_smwa.ipynb#6-model-2-random-forest-regressor)
#   - [7. Model 3 — Support Vector Regression (tuned kernel)](Predictive/3_models/combo/1_lag_smwa.ipynb#7-model-3-support-vector-regression-tuned-kernel)
#   - [8. Model 4 — XGBoost Regressor](Predictive/3_models/combo/1_lag_smwa.ipynb#8-model-4-xgboost-regressor)
#   - [9. Naive Baseline — Always Predict Zero](Predictive/3_models/combo/1_lag_smwa.ipynb#9-naive-baseline-always-predict-zero)
#   - [10. Model Comparison](Predictive/3_models/combo/1_lag_smwa.ipynb#10-model-comparison)
# - **[2 Lag Smwa Traditional](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb)**
#   - [Setup](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#setup)
#   - [1. Load Data & Compute Target](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#1-load-data-compute-target)
#   - [2. Train/Val/Test Split](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#2-trainvaltest-split)
#   - [3. CV Folds](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#3-cv-folds)
#   - [4. Helper Functions](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#4-helper-functions)
#   - [5. Model 1 — Ridge Regression](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#5-model-1-ridge-regression)
#   - [6. Model 2 — Random Forest Regressor](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#6-model-2-random-forest-regressor)
#   - [7. Model 3 — Support Vector Regression (tuned kernel)](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#7-model-3-support-vector-regression-tuned-kernel)
#   - [8. Model 4 — XGBoost Regressor](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#8-model-4-xgboost-regressor)
#   - [9. Naive Baseline — Always Predict Zero](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#9-naive-baseline-always-predict-zero)
#   - [10. Model Comparison](Predictive/3_models/combo/2_lag_smwa_traditional.ipynb#10-model-comparison)
#
# ### full
#
# - **[Full](Predictive/3_models/full/full.ipynb)**
#   - [Setup](Predictive/3_models/full/full.ipynb#setup)
#   - [1. Load Data & Compute Target](Predictive/3_models/full/full.ipynb#1-load-data-compute-target)
#   - [2. Train/Val/Test Split](Predictive/3_models/full/full.ipynb#2-trainvaltest-split)
#   - [3. CV Folds](Predictive/3_models/full/full.ipynb#3-cv-folds)
#   - [4. Helper Functions](Predictive/3_models/full/full.ipynb#4-helper-functions)
#   - [5. Model 1 — Ridge Regression](Predictive/3_models/full/full.ipynb#5-model-1-ridge-regression)
#   - [6. Model 2 — Random Forest Regressor](Predictive/3_models/full/full.ipynb#6-model-2-random-forest-regressor)
#   - [7. Model 3 — Support Vector Regression (tuned kernel)](Predictive/3_models/full/full.ipynb#7-model-3-support-vector-regression-tuned-kernel)
#   - [8. Model 4 — XGBoost Regressor](Predictive/3_models/full/full.ipynb#8-model-4-xgboost-regressor)
#   - [9. Naive Baseline — Always Predict Zero](Predictive/3_models/full/full.ipynb#9-naive-baseline-always-predict-zero)
#   - [10. Model Comparison](Predictive/3_models/full/full.ipynb#10-model-comparison)
