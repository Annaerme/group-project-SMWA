# %% [markdown]
# # Lecture 3: Exercise 2 - Students
#
# ## Objective
#
# The goal of this assignment is to perform **topic modeling** and **structured data analysis** using **Airbnb review and listing data**. You will apply **Latent Dirichlet Allocation (LDA)** to extract topics from reviews and explore structured patterns in the dataset.
#
# ## Tasks
#
# In this exercise, you will:
#
# 1. **Choose an Airbnb location** of interest (city)
# 2. **Download the data** from Inside Airbnb (reviews.csv and listings.csv)
# 3. **Perform topic modeling** using LDA on review text data
# 4. **Interpret the topics** discovered by the model
# 5. **Extend the analysis** based on your preferences:
#    - Compare different cities: Are there recurring topics?
#    - Explore neighborhood-level patterns: Do different neighborhoods have unique topics?
#    - Compare listing types: How do topics differ for entire homes vs. rooms?
#    - Analyze price classes: What topics appear in different price ranges?
#
# ## Data
#
# Download Airbnb data from **[Inside Airbnb](http://insideairbnb.com/get-the-data.html)**
#
# You will need:
# - **reviews.csv** - Contains review text and metadata
# - **listings.csv** - Contains listing information (location, type, price, etc.)
#
# Choose a location that interests you and has sufficient data (aim for at least 1000+ reviews).

# %% [markdown]
# ## Your Solution
#
# Complete the tasks below:

# %% [markdown]
# ### Step 1: Load the Data
#
# Download the Airbnb data for your chosen location from [Inside Airbnb](http://insideairbnb.com/get-the-data.html) and load it into pandas DataFrames.

# %%
# Your code here to load the data
# Hint:
# import pandas as pd
# reviews = pd.read_csv('path/to/reviews.csv')
# listings = pd.read_csv('path/to/listings.csv')
# 
# Explore the data:
# print(reviews.head())
# print(listings.head())

# %% [markdown]
# ### Step 2: Preprocess the Review Text
#
# Clean and preprocess the review text for topic modeling:
# - Convert to lowercase
# - Remove punctuation, numbers, and URLs
# - Remove stopwords
# - Tokenize the text

# %%
# Your code here for preprocessing
# Hint:
# - Remove rows with missing comments
# - Clean text (lowercase, remove punctuation, numbers, URLs)
# - Tokenize
# - Remove stopwords
# - Create a list of tokenized documents

# %% [markdown]
# ### Step 3: Create Document-Term Matrix
#
# Create a Document-Term Matrix (DTM) for LDA input.

# %%
# Your code here to create DTM
# Hint:
# - Use gensim to create a Dictionary and Corpus
# from gensim import corpora
# dictionary = corpora.Dictionary(tokenized_docs)
# corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

# %% [markdown]
# ### Step 4: Determine Optimal Number of Topics
#
# Test different numbers of topics (k) and select the optimal value using a coherence score or perplexity.

# %%
# Your code here to find optimal k
# Hint:
# - Train LDA models with different k values (e.g., 2-10)
# - Calculate coherence score for each model
# - Plot coherence scores
# from gensim.models import LdaModel
# from gensim.models.coherencemodel import CoherenceModel

# %% [markdown]
# ### Step 5: Train Final LDA Model
#
# Train the final LDA model with the optimal number of topics.

# %%
# Your code here to train final LDA model
# Hint:
# lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=optimal_k, random_state=42, passes=10)

# %% [markdown]
# ### Step 6: Interpret Topics
#
# Display the top words for each topic and interpret what each topic represents.

# %%
# Your code here to display and interpret topics
# Hint:
# - Use lda_model.print_topics() to see top words per topic
# - Create visualizations (bar charts, word clouds) for each topic
# - Manually interpret what each topic represents

# %% [markdown]
# ### Step 7: Assign Topics to Documents
#
# Determine the dominant topic for each review and explore which reviews belong to which topics.

# %%
# Your code here to assign topics to documents
# Hint:
# - For each document, get topic probabilities
# - Assign the topic with highest probability
# - Add topic assignments to your reviews dataframe
# - Display sample reviews for each topic

# %% [markdown]
# ### Step 8: Extend the Analysis (Choose Your Direction)
#
# Extend your analysis in one or more of the following ways:
# - **Compare different cities**: Load data from multiple cities and compare topics
# - **Neighborhood analysis**: Merge with listings data and analyze topics by neighborhood
# - **Listing type comparison**: Compare topics for entire homes vs. private rooms
# - **Price class analysis**: Analyze topics across different price ranges

# %%
# Your code here for extended analysis
# Choose your own direction and implement it here

# %% [markdown]
# ### Discussion Questions
#
# Answer these questions in your presentation:
#
# 1. **What location(s) did you choose and why?**
#    - Your answer here
#
# 2. **What topics did you discover? Give meaningful names to each topic.**
#    - Your answer here
#
# 3. **What are the top words for each topic and what do they represent?**
#    - Your answer here
#
# 4. **What patterns did you find in your extended analysis?**
#    - Your answer here
#
# 5. **What are the business implications of your findings?**
#    - Your answer here
#
# 6. **How could Airbnb hosts use this information to improve their listings?**
#    - Your answer here

# %% [markdown]
# ## Submission
#
# Prepare a **PowerPoint presentation** summarizing your topic modeling analysis.
#
# **Content to include:**
# - Your approach to data selection and preprocessing
# - LDA topic modeling results with topic interpretations
# - Visualization of topics (word clouds, bar charts, etc.)
# - Extended analysis findings (city/neighborhood/listing type comparisons)
# - Key insights and business implications
# - Clear explanations of your methodology and results
#
# **Duration:** 5-7 minutes per group
#
# Save your PowerPoint file as: **`TopicModeling_Program_GroupX.pptx`**
#
# Upload on **Ufora**: *Tools → Assignments*
