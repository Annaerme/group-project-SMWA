# %% [markdown]
# # Lecture 2: Exercise 1 - Students
#
# ## Objective
#
# The goal of this assignment is to **predict social media engagement** (retweets/reposts) using **machine learning** and identify which **words are most important** for driving engagement.
#
# ## Data
#
# Scrape **at least 1000 posts** about your topic of choice via **Mastodon** or **Bluesky**. Choose a hashtag or topic that interests you and is likely to generate sufficient posts with varied engagement levels.
#
# ## Task: Predicting Engagement with Random Forest
#
# In this task, you will:
#
# 1. **Scrape posts** from Mastodon or Bluesky, including **engagement metrics** (retweet/repost counts)
# 2. **Preprocess the text** and create a **document-term matrix** (DTM)
# 3. **Build a Random Forest model** to predict engagement based on word features
# 4. **Analyze feature importance** to identify which words drive engagement
# 5. **Create visualizations** (feature importance plot, partial dependence plots)
# 6. **Discuss your findings**:
#    - Which words are most predictive of high engagement?
#    - Do the results make sense for your topic?
#    - What insights can you draw about what drives engagement?

# %% [markdown]
# ## Your Solution
#
# Complete the tasks below:

# %% [markdown]
# ### Step 1: Collect Your Data
#
# Use one of the methods above to scrape at least 1000 posts. Store the text content in `texts` and engagement metrics in `engagement`.

# %%
# Your code here to collect data
# Store your posts in 'texts' and engagement metrics in 'engagement'
# (e.g., engagement = reblogs for Mastodon, or engagement = reposts for Bluesky)

# %% [markdown]
# ### Step 2: Preprocess the Text
#
# Clean your text data by:
# - Converting to lowercase
# - Removing punctuation
# - Removing numbers
# - Removing stopwords
# - Removing your search term/hashtag
#
# Apply preprocessing to all texts.

# %%
# Your code here for preprocessing
# Hint:
# - Create or reuse a preprocess_text() function
# - Apply to all texts
# - Store in 'texts_clean'

# %% [markdown]
# ### Step 3: Create Document-Term Matrix
#
# Use `CountVectorizer` to create a document-term matrix.
#
# **Important considerations:**
# - Use `min_df` parameter to remove rare words (e.g., min_df=5 means word must appear in at least 5 documents)
# - Use `max_df` parameter to remove very common words (e.g., max_df=0.95 removes words in >95% of documents)
# - Consider `max_features` to limit vocabulary size (e.g., max_features=500)
#
# These parameters help manage dimensionality and improve model performance.

# %%
# Your code here to create DTM
# Hint:
# - Import CountVectorizer from sklearn.feature_extraction.text
# - Set min_df=5, max_df=0.95 (or experiment with values)
# - Consider max_features to limit vocabulary
# - Fit and transform your preprocessed texts
# - Store as X (features) for the model

# %% [markdown]
# ### Step 4: Build Random Forest Model
#
# Build a Random Forest Regressor to predict engagement based on word features.
#
# Split your data into training and testing sets, then train the model.

# %%
# Your code here to build Random Forest model
# Hint:
# - Import train_test_split, RandomForestRegressor from sklearn
# - Split data: X_train, X_test, y_train, y_test (80/20 split)
# - Create RandomForestRegressor(n_estimators=100, random_state=42)
# - Fit the model
# - Evaluate on test set (calculate R² score and MSE)

# %% [markdown]
# ### Step 5: Analyze Feature Importance
#
# Extract and visualize the feature importance from your Random Forest model.
#
# Create a bar plot showing the top 20 most important words.

# %%
# Your code here to analyze feature importance
# Hint:
# - Get feature_importances_ from the model
# - Get feature names from vectorizer
# - Create DataFrame with words and importance scores
# - Sort by importance
# - Plot top 20 words using horizontal bar chart

# %% [markdown]
# ### Step 6: Partial Dependence Plots
#
# Create partial dependence plots for the top 3-5 most important words to understand their relationship with engagement.
#
# A partial dependence plot shows how the presence of a word affects predicted engagement.

# %%
# Your code here for partial dependence plots
# Hint:
# - Import PartialDependenceDisplay from sklearn.inspection
# - Get indices of top 3-5 important features
# - Use PartialDependenceDisplay.from_estimator()
# - Create subplots for multiple features

# %% [markdown]
# ### Discussion Questions
#
# Answer these questions in your presentation:
#
# 1. **What is your model's performance? (R² score, MSE)**
#    - Your answer here
#
# 2. **Which words are most important for predicting engagement?**
#    - Your answer here
#
# 3. **Do the important words make sense for your topic? Why or why not?**
#    - Your answer here
#
# 4. **What do the partial dependence plots reveal? How does word presence affect engagement?**
#    - Your answer here
#
# 5. **What strategies did you use to manage dimensionality (many words)?**
#    - Your answer here
#
# 6. **What insights about engagement drivers did you discover?**
#    - Your answer here

# %% [markdown]
# ## Submission
#
# Prepare a **PowerPoint presentation** summarizing your word graph analysis.
#
# **Content to include:**
# - Explanation of your **data collection approach**
# - **Word cloud comparison** and discussion of preprocessing impact
# - **Word graph visualization** and interpretation of structure and edge thickness
# - Explanation of your **model**, variable importance plot, and key insights
# - Focus on clearly explaining your **approach, results, and insights** for each exercise
#
# **Duration:** Part of a 5–7 minute group presentation covering all exercises.
#
# Save your PowerPoint file as: **`WordAnalysis_Program_GroupX.ppt`**
#
# Upload on **Ufora**: *Tools → Assignments*
