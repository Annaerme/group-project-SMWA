# %% [markdown]
# # Lecture 5: Exercise 2 - Students
#
# ## Objective
#
# The goal of this assignment is to compare **traditional LDA topic modeling** with **BERTopic**, a modern transformer-based approach. You will apply both methods to **Airbnb review data** (or another text dataset of your choice) and comprehensively analyze their strengths and weaknesses.
#
# ## Data
#
# You will use **Airbnb review data** from [Inside Airbnb](http://insideairbnb.com/get-the-data.html). You can use the same one as in Lecture 3. However, I would advise that you filter on English text and use a subsample of the data.
#
# ## Tasks
#
# ### Part 1: Data Preparation
#
# - **Load and preprocess data**
#   - Load your review/text dataset
#   - Create **two preprocessing pipelines**:
#     - Extensive preprocessing for LDA
#     - Minimal preprocessing for BERTopic
#   - Compare and contrast the two preprocessing approaches
#
# ### Part 2: Traditional LDA Topic Modeling
#
# - **Build document-term matrix**
#
# - **Determine optimal number of topics**
#   - Test a range of topic numbers (e.g., 2-10 or 2-11)
#   - Train LDA model for each number
#   - Calculate **coherence scores** (u_mass) for each model
#   - Visualize coherence scores across different topic numbers
#   - Select the optimal number based on coherence
#
# - **Train final LDA model**
#   - Train with optimal topic count
#   - Use appropriate hyperparameters (passes, iterations, alpha, eta)
#   - Calculate final coherence score
#
# - **Visualize LDA topics**
#
# ### Part 3: BERTopic Modeling (Automatic Topics)
#
# - **Configure BERTopic model**
#   - Choose an appropriate embedding model (e.g., `all-MiniLM-L6-v2` for speed, `all-mpnet-base-v2` for quality)
#   - Configure CountVectorizer
#   - Set appropriate clustering parameters (`min_topic_size`, `nr_topics='auto'`)
#
# - **Train BERTopic model**
#   - Fit the model on your preprocessed documents
#
# - **Calculate coherence score**
#   - Compare with LDA coherence
#
# - **Leverage BERTopic visualizations**
#   - Generate built-in visualizations:
#
# ### Part 4: BERTopic with Fixed Topic Count
#
# - **Train fixed BERTopic model**
#   - Configure BERTopic to match LDA's optimal number of topics
#   - Train and evaluate
#
# - **Calculate coherence**
#   - Compare coherence scores across all three models (LDA, BERTopic Auto, BERTopic Fixed)
#
# ### Part 5: Comprehensive Comparison
#
# - Create comparison visualizations
#
# - Analyze key differences
#
#
#
#
# ## Submission
#
# Prepare a **5-10 minute presentation** summarizing your findings.
#
# **Content:**
# - **Introduction**
#   - Dataset description and preprocessing overview
#
# - **LDA Results**
#   - Coherence score optimization process
#   - Final topic count and coherence score
#
# - **BERTopic Results**
#   - Automatic topic discovery (number of topics, coherence)
#   - Fixed topic count comparison
#
# - **Detailed Comparison**
#   - Side-by-side topic comparison
#
# - **Conclusions & Recommendations**
#   - Which approach performed best and why?
#   - When to use LDA vs BERTopic (practical guidelines)
#   - Best practices and lessons learned
#
# **Deliverables:**
# - **Presentation** with the naming: `Lecture5_Exercise2_Program_GroupX.pptx`
#
# Upload on Ufora: *Ufora > Tools > Assignments*.

# %% [markdown]
# ## Step 1: Import Libraries

# %%
# Your code here

# %% [markdown]
# ## Step 2: Load Data

# %%
# Your code here

# %% [markdown]
# ## Step 3: Preprocessing

# %%
# Your code here

# %% [markdown]
# ## Step 4: LDA Topic Modeling

# %%
# Your code here

# %% [markdown]
# ## Step 5: BERTopic (Automatic)

# %%
# Your code here

# %% [markdown]
# ## Step 6: BERTopic (Fixed Topics)

# %%
# Your code here

# %% [markdown]
# ## Step 7: Comprehensive Comparison

# %%
# Your code here
